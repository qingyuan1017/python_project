# %% [markdown]
# This module requires installing the packages: requests (jupyter dashboard->Conda)

# %% [markdown]
# # (2) JSON

# %%
# read from/write to string - json.loads / json.dumps
# read from/to files - json.load/json.dump
# directly to DataFrames - pd.read_json/pd.to_json

# %% [markdown]
# ## Read and Write JSON Strings

# %%
import json # many alternatives

# %%
# a string that specifies a JSON object
rec = """
{
"name": "Manuel Calevera",
"age": 40,
"friends":["Mercedes", "Glottis", "Olivia", "Sal"], 
"height":null,
"clues": {"a":1,"b":2}
}"""

# %%
# parse the string into a composition of dictionaries and lists
json.loads(rec)
# Out:
# {'age': 40,
#  'clues': {'a': 1, 'b': 2},
#  'friends': ['Mercedes', 'Glottis', 'Olivia', 'Sal'],
#  'height': None,
#  'name': 'Manuel Calevera'}

# %%
# Access data
obj = json.loads(rec)
type(obj)
# Out:
# dict

# %%
obj['age']
# Out:
# 40

# %%
obj['friends']
# Out:
# ['Mercedes', 'Glottis', 'Olivia', 'Sal']

# %%
obj['clues']
# Out:
# {'a': 1, 'b': 2}

# %%
obj['clues']['b']
# Out:
# 2

# %%
# Write Python object to string
json.dumps(obj)
# Out:
# '{"friends": ["Mercedes", "Glottis", "Olivia", "Sal"], "clues": {"a": 1, "b": 2}, "name": "Manuel Calevera", "age": 40, "height": null}'

# %% [markdown]
# ## Read and Write JSON Files

# %%
# open the "json_example.json" file for writing, and write in it the json object "obj"
f = open("json_example.json","w")
json.dump(obj, f)
f.close()

# %%
# print the newly created file
# !cat "json_example.json"
# Out:
# {"friends": ["Mercedes", "Glottis", "Olivia", "Sal"], "clues": {"a": 1, "b": 2}, "name": "Manuel Calevera", "age": 40, "height": null}

# %%
# parse JSON file using json.load
f = open("json_example.json","r")
print(json.load(f))
f.close()
# Out:
# {'friends': ['Mercedes', 'Glottis', 'Olivia', 'Sal'], 'clues': {'a': 1, 'b': 2}, 'name': 'Manuel Calevera', 'age': 40, 'height': None}

# %% [markdown]
# ## Exporting DataFrames to JSON files

# %%
import pandas as pd
df = pd.read_csv("data1.csv")
print(df)
# Out:
#   Language Wiki  Articles     Pages      Edits
# 0  English   en   5236357  40155905  847883223
# 1  Swedish   sv   3445556   6910072   36854915
# 2  Cebuano  ceb   2885091   5354566   10393518
# 3   German   de   1976573   5699722  162755765
# 4    Dutch   nl   1873902   3637030   48492474

# %%
# export DataFrame - split option {dictionary of values}
df.to_json("json_data_format_split.json", orient="split")
# !cat json_data_format_split.json
# Out:
# {"columns":["Language","Wiki","Articles","Pages","Edits"],"index":[0,1,2,3,4],"data":[["English","en",5236357,40155905,847883223],["Swedish","sv",3445556,6910072,36854915],["Cebuano","ceb",2885091,5354566,10393518],["German","de",1976573,5699722,162755765],["Dutch","nl",1873902,3637030,48492474]]}

# %%
# export DataFrame - records option (list of records)
df.to_json("json_data_format_records.json", orient="records")
# !cat json_data_format_records.json
# Out:
# [{"Language":"English","Wiki":"en","Articles":5236357,"Pages":40155905,"Edits":847883223},{"Language":"Swedish","Wiki":"sv","Articles":3445556,"Pages":6910072,"Edits":36854915},{"Language":"Cebuano","Wiki":"ceb","Articles":2885091,"Pages":5354566,"Edits":10393518},{"Language":"German","Wiki":"de","Articles":1976573,"Pages":5699722,"Edits":162755765},{"Language":"Dutch","Wiki":"nl","Articles":1873902,"Pages":3637030,"Edits":48492474}]

# %%
# export DataFrame - index option (records mapped by indices)
df.to_json("json_data_format_index.json", orient="index")
# !cat json_data_format_index.json
# Out:
# {"0":{"Language":"English","Wiki":"en","Articles":5236357,"Pages":40155905,"Edits":847883223},"1":{"Language":"Swedish","Wiki":"sv","Articles":3445556,"Pages":6910072,"Edits":36854915},"2":{"Language":"Cebuano","Wiki":"ceb","Articles":2885091,"Pages":5354566,"Edits":10393518},"3":{"Language":"German","Wiki":"de","Articles":1976573,"Pages":5699722,"Edits":162755765},"4":{"Language":"Dutch","Wiki":"nl","Articles":1873902,"Pages":3637030,"Edits":48492474}}

# %%
# export DataFrame - columns option (similar to index with primary mapping being column name)
df.to_json("json_data_format_columns.json", orient="columns")
# !cat json_data_format_columns.json
# Out:
# {"Language":{"0":"English","1":"Swedish","2":"Cebuano","3":"German","4":"Dutch"},"Wiki":{"0":"en","1":"sv","2":"ceb","3":"de","4":"nl"},"Articles":{"0":5236357,"1":3445556,"2":2885091,"3":1976573,"4":1873902},"Pages":{"0":40155905,"1":6910072,"2":5354566,"3":5699722,"4":3637030},"Edits":{"0":847883223,"1":36854915,"2":10393518,"3":162755765,"4":48492474}}

# %%
# export DataFrame - values option (list of lists without indeices)
df.to_json("json_data_format_values.json", orient="values")
# !cat json_data_format_values.json
# Out:
# [["English","en",5236357,40155905,847883223],["Swedish","sv",3445556,6910072,36854915],["Cebuano","ceb",2885091,5354566,10393518],["German","de",1976573,5699722,162755765],["Dutch","nl",1873902,3637030,48492474]]

# %%
# Importing JSON files to DataFrames
pd.read_json("json_data_format_columns.json", orient="columns")
# Out:
#    Articles      Edits Language     Pages Wiki
# 0   5236357  847883223  English  40155905   en
# 1   3445556   36854915  Swedish   6910072   sv
# 2   2885091   10393518  Cebuano   5354566  ceb
# 3   1976573  162755765   German   5699722   de
# 4   1873902   48492474    Dutch   3637030   nl

# %%
df # column order could change in the process
# Out:
#   Language Wiki  Articles     Pages      Edits
# 0  English   en   5236357  40155905  847883223
# 1  Swedish   sv   3445556   6910072   36854915
# 2  Cebuano  ceb   2885091   5354566   10393518
# 3   German   de   1976573   5699722  162755765
# 4    Dutch   nl   1873902   3637030   48492474

# %% [markdown]
# ##  web-services

# %%
import requests
import json

# %%
page = requests.get('https://api.opencorporates.com/v0.4/companies/search?q=barclays+bank')

# %%
page.text
# Out:
# '{"api_version":"0.4","results":{"companies":[{"company":{"name":"BARCLAYS BANK","company_number":"0870373575","jurisdiction_code":"be","incorporation_date":"2004-12-03","dissolution_date":null,"company_type":"Entreprise \\u00e9trang\\u00e8re","registry_url":"https://kbopub.economie.fgov.be/kbopub/toonondernemingps.html?lang=fr&ondernemingsnummer=0870373575","branch_status":"branch of an out-of-jurisdiction company","inactive":false,"current_status":"Soci\\u00e9t\\u00e9 En Nom Collectif","created_at":"2014-06-08T23:43:37+00:00","updated_at":"2016-12-15T22:59:29+00:00","retrieved_at":"2016-12-02T00:00:00+00:00","opencorporates_url":"https://opencorporates.com/companies/be/0870373575","previous_names":[],"source":{"publisher":"La Banque-Carrefour des Entreprises","url":"http://economie.fgov.be/fr/entreprises/bce/pub/opendata/","retrieved_at":"2016-12-02T00:00:00+00:00"},"registered_address":{"street_address":"LOMBARD STREET 54","locality":"LONDON","region":null,"postal_code":"EC3P 3AM","country":"Grande-Bretagne"},"registered_address_in_full":"LOMBARD STREET 54, LONDON, EC3P 3AM","restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK","company_number":"PR34","jurisdiction_code":"mt","incorporation_date":"2005-04-28","dissolution_date":null,"company_type":null,"registry_url":null,"branch_status":null,"inactive":null,"current_status":null,"created_at":"2011-05-05T01:45:46+00:00","updated_at":"2016-12-30T13:26:34+00:00","retrieved_at":"2016-12-27T20:05:04+00:00","opencorporates_url":"https://opencorporates.com/companies/mt/PR34","previous_names":[],"source":{"publisher":"The Malta Financial Services Authority","url":"http://rocsupport.mfsa.com.mt/","retrieved_at":"2016-12-27T20:05:04+00:00"},"registered_address":{"street_address":"31 Regent House Bisazza Street","locality":null,"region":null,"postal_code":null,"country":"Malta"},"registered_address_in_full":"31 Regent House Bisazza Street","restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK ( DOMINION COLONIAL AND OVERSSEAS)","company_number":"ARC35A","jurisdiction_code":"ug","incorporation_date":null,"dissolution_date":null,"company_type":"Archives","registry_url":null,"branch_status":null,"inactive":false,"current_status":"Registered","created_at":"2014-06-01T07:12:13+00:00","updated_at":"2016-11-29T17:26:57+00:00","retrieved_at":"2016-11-28T00:27:49+00:00","opencorporates_url":"https://opencorporates.com/companies/ug/ARC35A","previous_names":[],"source":{"publisher":"Uganda Registration Services Bureau ","url":"http://www.ursb.go.ug/","retrieved_at":"2016-11-28T00:27:49+00:00"},"registered_address":null,"registered_address_in_full":null,"restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK (HONG KONG NOMINEES) LIMITED","company_number":"0040910","jurisdiction_code":"hk","incorporation_date":"1974-11-26","dissolution_date":null,"company_type":"Private company limited by shares","registry_url":null,"branch_status":null,"inactive":false,"current_status":"Live","created_at":"2014-08-31T23:41:42+00:00","updated_at":"2016-08-20T14:10:17+00:00","retrieved_at":"2016-08-19T19:45:15+00:00","opencorporates_url":"https://opencorporates.com/companies/hk/0040910","previous_names":[{"start_date":"1974-11-26","company_name":"BARCLAYS BANK (HONG KONG NOMINEES) LIMITED"}],"source":{"publisher":"Hong Kong Companies Registry","url":"http://www.icris.cr.gov.hk/","retrieved_at":"2016-08-19T19:45:15+00:00"},"registered_address":null,"registered_address_in_full":null,"restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK (LONDON AND INTERNATIONAL) LIMITED","company_number":"00747985","jurisdiction_code":"gb","incorporation_date":"1963-01-24","dissolution_date":"2008-05-13","company_type":"Private Limited Company","registry_url":"https://beta.companieshouse.gov.uk/company/00747985","branch_status":null,"inactive":true,"current_status" ...

# %%
json.loads(page.text)
# Out:
# {'api_version': '0.4',
#  'results': {'companies': [{'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '0870373575',
#      'company_type': 'Entreprise étrangère',
#      'created_at': '2014-06-08T23:43:37+00:00',
#      'current_status': 'Société En Nom Collectif',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '2004-12-03',
#      'jurisdiction_code': 'be',
#      'name': 'BARCLAYS BANK',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/be/0870373575',
#      'previous_names': [],
#      'registered_address': {'country': 'Grande-Bretagne',
#       'locality': 'LONDON',
#       'postal_code': 'EC3P 3AM',
#       'region': None,
#       'street_address': 'LOMBARD STREET 54'},
#      'registered_address_in_full': 'LOMBARD STREET 54, LONDON, EC3P 3AM',
#      'registry_url': 'https://kbopub.economie.fgov.be/kbopub/toonondernemingps.html?lang=fr&ondernemingsnummer=0870373575',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-12-02T00:00:00+00:00',
#      'source': {'publisher': 'La Banque-Carrefour des Entreprises',
#       'retrieved_at': '2016-12-02T00:00:00+00:00',
#       'url': 'http://economie.fgov.be/fr/entreprises/bce/pub/opendata/'},
#      'updated_at': '2016-12-15T22:59:29+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': 'PR34',
#      'company_type': None,
#      'created_at': '2011-05-05T01:45:46+00:00',
#      'current_status': None,
#      'dissolution_date': None,
#      'inactive': None,
#      'incorporation_date': '2005-04-28',
#      'jurisdiction_code': 'mt',
#      'name': 'BARCLAYS BANK',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/mt/PR34',
#      'previous_names': [],
#      'registered_address': {'country': 'Malta',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '31 Regent House Bisazza Street'},
#      'registered_address_in_full': '31 Regent House Bisazza Street',
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-12-27T20:05:04+00:00',
#      'source': {'publisher': 'The Malta Financial Services Authority',
#       'retrieved_at': '2016-12-27T20:05:04+00:00',
#       'url': 'http://rocsupport.mfsa.com.mt/'},
#      'updated_at': '2016-12-30T13:26:34+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': 'ARC35A',
#      'company_type': 'Archives',
#      'created_at': '2014-06-01T07:12:13+00:00',
#      'current_status': 'Registered',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': None,
#      'jurisdiction_code': 'ug',
#      'name': 'BARCLAYS BANK ( DOMINION COLONIAL AND OVERSSEAS)',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ug/ARC35A',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-28T00:27:49+00:00',
#      'source': {'publisher': 'Uganda Registration Services Bureau ',
#       'retrieved_at': '2016-11-28T00:27:49+00:00',
#       'url': 'http://www.ursb.go.ug/'},
#      'updated_at': '2016-11-29T17:26:57+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '0040910',
#      'company_type': 'Private company limited by shares',
#      'created_at': '2014-08-31T23:41:42+00:00',
#      'current_status': 'Live',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '1974-11-26',
#      'jurisdiction_code': 'hk',
#      'name': 'BARCLAYS BANK (HONG KONG NOMINEES) LIMITED',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/hk/0040910',
#      'previous_names': [{'company_name': 'BARCLAYS BANK (HONG KONG NOMINEES) LIMITED',
#        'start_date': '1974-11-26'}],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-08-19T19:45:15+00:00',
#      'source': {'publisher': 'Hong Kong Companies Registry',
#       'retrieved_at': '2016-08-19T19:45:15+00:00',
#       'url': 'http://www.icris.cr.gov.hk/'},
#      'updated_at': '2016-08-20T14:10:17+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '00747985',
#      'company_type': 'Private Limited Company',
#      'created_at': '2010-10-21T16:36:19+00:00',
#      'current_status': 'Dissolved',
#      'dissolution_date': '2008-05-13',
#      'inactive': True,
#      'incorporation_date': '1963-01-24',
#      'jurisdiction_code': 'gb',
#      'name': 'BARCLAYS BANK (LONDON AND INTERNATIONAL) LIMITED',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/gb/00747985',
#      'previous_names': [],
#      'registered_address': {'country': 'United Kingdom',
#       'locality': 'LONDON',
#       'postal_code': 'EC3P 3AH',
#       'region': None,
#       'street_address': '54 LOMBARD STREET'},
#      'registered_address_in_full': '54 LOMBARD STREET, LONDON, EC3P 3AH',
#      'registry_url': 'https://beta.companieshouse.gov.uk/company/00747985',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2015-03-14T00:00:53+00:00',
#      'source': {'publisher': 'UK Companies House',
#       'retrieved_at': '2015-03-14T00:00:53+00:00',
#       'terms': 'UK Crown Copyright',
#       'url': 'http://xmlgw.companieshouse.gov.uk/'},
#      'updated_at': '2015-12-13T12:49:26+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '198003638Z',
#      'company_type': None,
#      'created_at': '2011-04-13T11:48:37+00:00',
#      'current_status': 'Live Company',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': None,
#      'jurisdiction_code': 'sg',
#      'name': 'BARCLAYS BANK (SINGAPORE NOMINEES) PTE LTD',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/sg/198003638Z',
#      'previous_names': [],
#      'registered_address': {'country': 'Singapore',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)'},
#      'registered_address_in_full': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)',
#      'registry_url': 'https://www.tis.bizfile.gov.sg/ngbtisinternet/faces/oracle/webcenter/portalapp/pages/productlisting/ishopProductListing.jspx?EntityNo=198003638Z&_afrLoop=356552297613828&_afrWindowMode=0&_afrWindowId=null',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-23T03:56:51+00:00',
#      'source': {'publisher': 'Singapore Accounting and Corporate Regulatory Authority',
#       'retrieved_at': '2016-11-23T03:56:51+00:00',
#       'url': 'http://www.bizfile.gov.sg'},
#      'updated_at': '2016-11-30T16:43:37+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '199205730M',
#      'company_type': None,
#      'created_at': '2011-04-13T11:48:37+00:00',
#      'current_status': 'Live Company',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': None,
#      'jurisdiction_code': 'sg',
#      'name': 'BARCLAYS BANK (SOUTH EAST ASIA) NOMINEES PTE LTD',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/sg/199205730M',
#      'previous_names': [],
#      'registered_address': {'country': 'Singapore',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)'},
#      'registered_address_in_full': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)',
#      'registry_url': 'https://www.tis.bizfile.gov.sg/ngbtisinternet/faces/oracle/webcenter/portalapp/pages/productlisting/ishopProductListing.jspx?EntityNo=199205730M&_afrLoop=288507653680897&_afrWindowMode=0&_afrWindowId=null',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-21T18:13:11+00:00',
#      'source': {'publisher': 'Singapore Accounting and Corporate Regulatory Authority',
#       'retrieved_at': '2016-11-21T18:13:11+00:00',
#       'url': 'http://www.bizfile.gov.sg'},
#      'updated_at': '2016-11-30T19:58:50+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '2162687',
#      'company_type': 'Non-distributing corporation with 50 or fewer shareholders',
#      'created_at': '2011-06-03T18:45:19+00:00',
#      'current_status': 'Inactive   Amalgamated',
#      'dissolution_date': '1992-11-01',
#      'inactive': True,
#      'incorporation_date': '1987-03-02',
#      'jurisdiction_code': 'ca',
#      'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ca/2162687',
#      'previous_names': [{'company_name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#        'end_date': '1989-05-26T00:00:00',
#        'start_date': '1987-03-02T00:00:00'},
#       {'company_name': 'CORPORATION FINANCIERE AGRICULTURELLE DE LA BANQUE BARCLAYS',
#        'end_date': '1989-05-26T00:00:00',
#        'start_date': '1987-03-02T00:00:00'}],
#      'registered_address': {'country': 'CA',
#       'locality': 'CALGARY',
#       'postal_code': 'T2P3S8',
#       'region': 'AB',
#       'street_address': '530  8TH AVENUE S.W.\nSUITE 2120'},
#      'registered_address_in_full': '530  8TH AVENUE S.W.\nSUITE 2120, CALGARY, AB, T2P3S8',
#      'registry_url': 'https://www.ic.gc.ca/app/scr/cc/CorporationsCanada/fdrlCrpDtls.html?corpId=2162687',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-04-17T17:51:34+00:00',
#      'source': {'publisher': 'Corporations Canada',
#       'retrieved_at': '2016-04-17T17:51:34+00:00',
#       'url': 'https://www.ic.gc.ca/app/scr/cc/CorporationsCanada/fdrlCrpDtls.html?corpId=2162687'},
#      'updated_at': '2016-07-15T22:22:15+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '1603D',
#      'company_type': 'Company - With Share Capital - Dominion',
#      'created_at': '2014-10-27T23:46:25+00:00',
#      'current_status': 'Cancelled   Voluntary',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': '1987-03-06',
#      'jurisdiction_code': 'ca_nl',
#      'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ca_nl/1603D',
#      'previous_names': [],
#      'registered_address': {'country': 'Canada',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': "O'REILLY,NOSEWORTHY, 323, DUCKWORTH ST,ST JOHN'S,NF"},
#      'registered_address_in_full': "O'REILLY,NOSEWORTHY, 323, DUCKWORTH ST,ST JOHN'S,NF",
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-12-12T01:09:37+00:00',
#      'source': {'publisher': 'Government of Newfoundland & Labrador Registry of Companies',
#       'retrieved_at': '2016-12-12T01:09:37+00:00',
#       'url': 'https://cado.eservices.gov.nl.ca'},
#      'updated_at': '2016-12-15T21:21:09+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '1765413',
#      'company_type': 'Extra-Provincial Financial Institution',
#      'created_at': '2012-09-27T09:00:24+00:00',
#      'current_status': 'Revoked By Request',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': '1987-03-06',
#      'jurisdiction_code': 'ca_ns',
#      'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ca_ns/1765413',
#      'previous_names': [],
#      'registered_address': {'country': 'Canada',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': 'STE. 2120, 530-8TH AVENUE S.W.\nCALGARY AB Canada T2P3S8'},
#      'registered_address_in_full': 'STE. 2120, 530-8TH AVENUE S.W.\nCALGARY AB Canada T2P3S8',
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2015-10-17T05:35:56+00:00',
#      'source': {'publisher': 'Nova Scotia Registry of Joint Stock Companies',
#       'retrieved_at': '2015-10-17T05:35:56+00:00',
#       'url': 'https://rjsc.gov.ns.ca/rjsc/'},
#      'updated_at': '2016-06-23T14:42:41+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '70805',
#      'company_type': None,
#      'created_at': '2014-11-08T22:48:32+00:00',
#      'current_status': 'F',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': None,
#      'jurisdiction_code': 'ca_nb',
#      'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION CORPORATION FINANCIERE AGRICULTURELLE DE LA BANQUE BARCLAYS',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ca_nb/70805',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2017-01-07T05:25:06+00:00',
#      'source': {'publisher': 'New Brunswick Corporate Affairs Registry Database',
#       'retrieved_at': '2017-01-07T05:25:06+00:00',
#       'url': 'https://www.pxw2.snb.ca/card_online/Search/search.aspx'},
#      'updated_at': '2017-01-07T15:07:56+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '11412-1',
#      'company_type': 'Foreign Branches Company',
#      'created_at': '2013-03-19T04:01:31+00:00',
#      'current_status': 'Deleted Without Payment',
#      'dissolution_date': '1992-06-10',
#      'inactive': True,
#      'incorporation_date': '1981-10-06',
#      'jurisdiction_code': 'bh',
#      'name': 'BARCLAYS BANK B.L.C',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/bh/11412-1',
#      'previous_names': [],
#      'registered_address': {'country': 'Bahrain',
#       'locality': "MANAMA/DIPL'AREA",
#       'postal_code': None,
#       'region': None,
#       'street_address': 'Flat 31, Building 419, Road 1705, Block 317'},
#      'registered_address_in_full': "Flat 31, Building 419, Road 1705, Block 317, MANAMA/DIPL'AREA",
#      'registry_url': "http://www.moic.gov.bh/CReServices/inquiry/javascript:__doPostBack('grdCR$ctl07$lnkCrBr','')",
#      'restricted_for_marketing': None,
#      'retrieved_at': '2014-04-09T18:41:49+00:00',
#      'source': {'publisher': 'Bahrain Ministry Of Industry And Commerce',
#       'retrieved_at': '2014-04-09T18:41:49+00:00',
#       'url': "http://www.moic.gov.bh/CReServices/inquiry/javascript:__doPostBack('grdCR$ctl07$lnkCrBr','')"},
#      'updated_at': '2014-04-09T23:48:04+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': 'F14031579',
#      'company_type': None,
#      'created_at': '2012-03-03T07:07:39+00:00',
#      'current_status': 'Incorporated',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '2011-03-24',
#      'jurisdiction_code': 'us_md',
#      'name': 'BARCLAYS BANK DELAWARE',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_md/F14031579',
#      'previous_names': [],
#      'registered_address': {'country': 'United States',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '100 S WEST ST\nWILMINGTON, DE 19801'},
#      'registered_address_in_full': '100 S WEST ST\nWILMINGTON, DE 19801',
#      'registry_url': 'http://sdatcert3.resiusa.org/UCC-Charter/Pages/CharterSearch/default.aspx',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-09-04T17:59:47+00:00',
#      'source': {'publisher': 'Maryland Department of Assessments & Taxation',
#       'retrieved_at': '2016-09-04T17:59:47+00:00',
#       'url': 'http://sdat.dat.maryland.gov/ucc-charter/Pages/CharterSearch/default.aspx'},
#      'updated_at': '2016-10-05T02:54:57+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '3227623',
#      'company_type': 'Corporation',
#      'created_at': '2015-10-15T00:29:27+00:00',
#      'current_status': None,
#      'dissolution_date': None,
#      'inactive': None,
#      'incorporation_date': '2001-03-21',
#      'jurisdiction_code': 'us_de',
#      'name': 'BARCLAYS BANK DELAWARE',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_de/3227623',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-07-21T02:35:45+00:00',
#      'source': {'publisher': 'Delaware Department of State: Division of Corporations',
#       'retrieved_at': '2016-07-21T02:35:45+00:00',
#       'url': 'http://www.corp.delaware.gov/'},
#      'updated_at': '2016-10-05T02:54:58+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': 'EXTUID_3204',
#      'company_type': 'RC - Registered Private Company',
#      'created_at': '2010-11-19T03:37:24+00:00',
#      'current_status': 'Dissolved',
#      'dissolution_date': '2003-05-28',
#      'inactive': True,
#      'incorporation_date': '1969-01-09',
#      'jurisdiction_code': 'je',
#      'name': 'BARCLAYS BANK FINANCE COMPANY (JERSEY) LIMITED',
#      'native_company_number': '3564',
#      'opencorporates_url': 'https://opencorporates.com/companies/je/EXTUID_3204',
#      'previous_names': [],
#      'registered_address': {'country': None,
#       'locality': 'St Helier',
#       'postal_code': None,
#       'region': None,
#       'street_address': '29/31 The Esplanade'},
#      'registered_address_in_full': '29/31 The Esplanade, St Helier',
#      'registry_url': 'https://www.jerseyfsc.org/registry/documentsearch/NameDetail.aspx?id=3204',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-22T23:16:27+00:00',
#      'source': {'publisher': 'Jersey Financial Services Commission',
#       'retrieved_at': '2016-11-22T23:16:27+00:00',
#       'url': 'https://www.jerseyfsc.org/registry/documentsearch/NameDetail.aspx?id=3204'},
#      'updated_at': '2016-11-23T00:18:49+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '10208960',
#      'company_type': 'Foreign Corp',
#      'created_at': '2016-01-23T00:54:09+00:00',
#      'current_status': 'Active',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '2015-05-13',
#      'jurisdiction_code': 'us_ne',
#      'name': 'BARCLAYS BANK INC',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ne/10208960',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': 'https://www.nebraska.gov/sos/corp/corpsearch.cgi?acct-number=10208960',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-01-19T13:08:58+00:00',
#      'source': {'publisher': 'Nebraska Secretary of State',
#       'retrieved_at': '2016-01-19T13:08:58+00:00',
#       'url': 'https://www.nebraska.gov/sos/corp/corpsearch.cgi?acct-number=10208960'},
#      'updated_at': '2016-01-23T02:34:16+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': 'F001323223',
#      'company_type': 'Gen. Business - For Profit',
#      'created_at': '2016-02-21T02:23:16+00:00',
#      'current_status': 'Good Standing',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '2015-09-04',
#      'jurisdiction_code': 'us_mo',
#      'name': 'BARCLAYS BANK INC.',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_mo/F001323223',
#      'previous_names': [],
#      'registered_address': {'country': 'United States',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '120 South Central Ave\nClayton, MO 63105'},
#      'registered_address_in_full': '120 South Central Ave\nClayton, MO 63105',
#      'registry_url': 'https://bsd.sos.mo.gov/BusinessEntity/BusinessEntityDetail.aspx?page=beSearch&ID=3746202',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-08-04T03:18:35+00:00',
#      'source': {'publisher': 'Missouri Secretary of State',
#       'retrieved_at': '2016-08-04T03:18:35+00:00',
#       'url': 'https://bsd.sos.mo.gov/BusinessEntity/BusinessEntityDetail.aspx?page=beSearch&ID=3746202'},
#      'updated_at': '2016-08-08T14:11:18+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '0324949',
#      'company_type': 'Foreign Profit Corporation',
#      'created_at': '2016-12-01T04:14:54+00:00',
#      'current_status': 'Active',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '2016-11-28',
#      'jurisdiction_code': 'us_vt',
#      'name': 'BARCLAYS BANK INC.',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_vt/0324949',
#      'previous_names': [],
#      'registered_address': {'country': 'United States',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '1 Churchill Place, London, E145H, GBR'},
#      'registered_address_in_full': '1 Churchill Place, London, E145H, GBR',
#      'registry_url': 'https://www.vtsosonline.com/online/BusinessInquire/BusinessInformation?businessID=0324949',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2017-01-09T03:30:44+00:00',
#      'source': {'publisher': 'Vermont Secretary of State: Corporations Division',
#       'retrieved_at': '2017-01-09T03:30:44+00:00',
#       'url': 'http://www.sec.state.vt.us/corps/corp.htm'},
#      'updated_at': '2017-01-09T13:27:17+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '01048020',
#      'company_type': 'Private Limited Company',
#      'created_at': '2011-04-25T10:43:36+00:00',
#      'current_status': 'Dissolved',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': '1972-03-30',
#      'jurisdiction_code': 'gb',
#      'name': 'BARCLAYS BANK INTERNATIONAL INVESTMENTS HOLDINGS LIMITED',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/gb/01048020',
#      'previous_names': [],
#      'registered_address': {'country': 'United Kingdom',
#       'locality': 'LONDON',
#       'postal_code': 'EC4A 3TR',
#       'region': None,
#       'street_address': 'HILL HOUSE, 1 LITTLE NEW STREET'},
#      'registered_address_in_full': 'HILL HOUSE, 1 LITTLE NEW STREET, LONDON, EC4A 3TR',
#      'registry_url': 'https://beta.companieshouse.gov.uk/company/01048020',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2011-05-03T05:36:17+00:00',
#      'source': {'publisher': 'UK Companies House',
#       'retrieved_at': '2011-05-03T05:36:17+00:00',
#       'terms': 'UK Crown Copyright',
#       'url': 'http://xmlgw.companieshouse.gov.uk/'},
#      'updated_at': '2015-12-13T23:57:59+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '49396015',
#      'company_type': 'Anden udenlandsk virksomhed',
#      'created_at': '2016-01-01T21:07:17+00:00',
#      'current_status': None,
#      'dissolution_date': '1989-12-31',
#      'inactive': True,
#      'incorporation_date': '1974-09-20',
#      'jurisdiction_code': 'dk',
#      'name': 'BARCLAYS BANK INTERNATIONAL LTD',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/dk/49396015',
#      'previous_names': [{'company_name': 'BARCLAYS BANK INTERNATIONAL LTD',
#        'end_date': '1989-12-31',
#        'start_date': '1974-09-20'}],
#      'registered_address': {'country': 'Denmark',
#       'locality': 'København K',
#       'postal_code': '1061',
#       'region': None,
#       'street_address': 'Ved Stranden 8'},
#      'registered_address_in_full': 'Ved Stranden 8, København K, 1061',
#      'registry_url': 'http://datacvr.virk.dk/data/visenhed?enhedstype=virksomhed&id=49396015',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2017-01-02T01:09:15+00:00',
#      'source': {'publisher': 'Det centrale virksomhedsregister',
#       'retrieved_at': '2017-01-02T01:09:15+00:00',
#       'terms': 'Vilkår for brug af danske offentlige data/CVR.dk licence',
#       'terms_url': 'http://www.cvr.dk/Site/Forms/CMS/DisplayPage.aspx?pageid=91',
#       'url': 'http://datacvr.virk.dk/data/'},
#      'updated_at': '2017-01-12T01:05:35+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '1678',
#      'company_type': 'Private',
#      'created_at': '2011-07-25T05:32:46+00:00',
#      'current_status': 'Dissolved',
#      'dissolution_date': '1992-10-16',
#      'inactive': True,
#      'incorporation_date': '1893-08-15',
#      'jurisdiction_code': 'ie',
#      'name': 'BARCLAYS BANK IRELAND LIMITED',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ie/1678',
#      'previous_names': [],
#      'registered_address': {'country': 'Ireland',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': "47/49, ST. STEPHEN'S GREEN, DUBLIN 2."},
#      'registered_address_in_full': "47/49, ST. STEPHEN'S GREEN, DUBLIN 2.",
#      'registry_url': 'http://www.cro.ie/search/CompanyDetails.aspx?id=1678&type=C',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-29T13:11:45+00:00',
#      'source': {'publisher': 'Ireland Companies Registration Office',
#       'retrieved_at': '2016-11-29T13:11:45+00:00',
#       'terms': 'CRO Open Services licence',
#       'url': 'https://services.cro.ie/'},
#      'updated_at': '2016-11-29T13:11:45+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '396330',
#      'company_type': 'PLC - Public Limited Company',
#      'created_at': '2011-07-25T05:32:46+00:00',
#      'current_status': 'Normal',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '2005-01-12',
#      'jurisdiction_code': 'ie',
#      'name': 'BARCLAYS BANK IRELAND PUBLIC LIMITED COMPANY',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ie/396330',
#      'previous_names': [],
#      'registered_address': {'country': 'Ireland',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': 'TWO PARK PLACE, HATCH STREET, DUBLIN 2.'},
#      'registered_address_in_full': 'TWO PARK PLACE, HATCH STREET, DUBLIN 2.',
#      'registry_url': 'http://www.cro.ie/search/CompanyDetails.aspx?id=396330&type=C',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2017-01-03T00:38:31+00:00',
#      'source': {'publisher': 'Ireland Companies Registration Office',
#       'retrieved_at': '2017-01-03T00:38:31+00:00',
#       'terms': 'CRO Open Services licence',
#       'url': 'https://services.cro.ie/'},
#      'updated_at': '2017-01-03T00:38:31+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': 'Z13536230',
#      'company_type': None,
#      'created_at': '2012-03-03T07:07:40+00:00',
#      'current_status': 'Revived',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '2010-04-22',
#      'jurisdiction_code': 'us_md',
#      'name': 'BARCLAYS BANK LC A/K/A BARCLAYS BANK PLC',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_md/Z13536230',
#      'previous_names': [],
#      'registered_address': {'country': 'United States',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '1 CHURCHILL PL\nLONDON,'},
#      'registered_address_in_full': '1 CHURCHILL PL\nLONDON,',
#      'registry_url': 'http://sdatcert3.resiusa.org/UCC-Charter/Pages/CharterSearch/default.aspx',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-09-12T00:41:34+00:00',
#      'source': {'publisher': 'Maryland Department of Assessments & Taxation',
#       'retrieved_at': '2016-09-12T00:41:34+00:00',
#       'url': 'http://sdat.dat.maryland.gov/ucc-charter/Pages/CharterSearch/default.aspx'},
#      'updated_at': '2016-10-08T01:17:02+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '0726501',
#      'company_type': 'Foreign Corporation',
#      'created_at': '2015-06-22T20:51:03+00:00',
#      'current_status': 'I   Inactive',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': None,
#      'jurisdiction_code': 'us_ky',
#      'name': 'BARCLAYS BANK LIMITED',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ky/0726501',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': 'https://app.sos.ky.gov/ftshow/(S(4g2sxj3uxdikdps4zvp2qtdl))/default.aspx?path=ftsearch&id=0726501&ct=09&cs=99999',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-10-12T06:34:44+00:00',
#      'source': {'publisher': 'Kentucky Secretary Of State',
#       'retrieved_at': '2016-10-12T06:34:44+00:00',
#       'url': 'https://app.sos.ky.gov/ftshow/(S(4g2sxj3uxdikdps4zvp2qtdl))/default.aspx?path=ftsearch&id=0726501&ct=09&cs=99999'},
#      'updated_at': '2016-10-25T02:26:57+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '0677543',
#      'company_type': 'Foreign Corporation',
#      'created_at': '2015-06-22T15:01:32+00:00',
#      'current_status': 'I   Inactive',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': None,
#      'jurisdiction_code': 'us_ky',
#      'name': 'BARCLAYS BANK LIMTED',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ky/0677543',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': 'https://app.sos.ky.gov/ftshow/(S(1b2xjuppwki5twd4l5b14itt))/default.aspx?path=ftsearch&id=0677543&ct=09&cs=99999',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-10-06T08:08:31+00:00',
#      'source': {'publisher': 'Kentucky Secretary Of State',
#       'retrieved_at': '2016-10-06T08:08:31+00:00',
#       'url': 'https://app.sos.ky.gov/ftshow/(S(1b2xjuppwki5twd4l5b14itt))/default.aspx?path=ftsearch&id=0677543&ct=09&cs=99999'},
#      'updated_at': '2016-10-09T13:49:57+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': 'C0489490',
#      'company_type': 'Domestic Stock',
#      'created_at': '2011-09-14T21:24:05+00:00',
#      'current_status': 'Merged Out',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': '1965-04-20',
#      'jurisdiction_code': 'us_ca',
#      'name': 'BARCLAYS BANK OF CALIFORNIA',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ca/C0489490',
#      'previous_names': [],
#      'registered_address': {'country': 'United States',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '111 PINE STREET STE. 200,\nSAN FRANCISCO, CA 94111'},
#      'registered_address_in_full': '111 PINE STREET STE. 200,\nSAN FRANCISCO, CA 94111',
#      'registry_url': 'https://businessfilings.sos.ca.gov/frmDetail.asp?CorpID=00489490',
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-24T08:22:47+00:00',
#      'source': {'publisher': 'California Secretary of State',
#       'retrieved_at': '2016-11-24T08:22:47+00:00',
#       'url': 'https://businessfilings.sos.ca.gov/frmDetail.asp?CorpID=00489490'},
#      'updated_at': '2016-12-10T20:59:16+00:00'}},
#    {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#      'company_number': '1956986',
#      'company_type': 'Extra-Provincial Financial Institution',
#      'created_at': '2012-09-27T01:51:12+00:00',
#      'current_status': 'Revoked By Request',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': '1989-06-01',
#      'jurisdiction_code': 'ca_ns',
#      'name': 'BARCLAYS BANK OF CANADA',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ca_ns/1956986',
#      'previous_names': [],
#      'registered_address': {'country': 'Canada',
#       'locality': None,
#       'postal_code': None,
#       'region': None,
#       'street_address': '304 BAY ST\nTORONTO ON Canada M5H2P2'},
#      'registered_address_in_full': '304 BAY ST\nTORONTO ON Canada M5H2P2',
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2015-10-19T09:08:00+00:00',
#      'source': {'publisher': 'Nova Scotia Registry of Joint Stock Companies',
#       'retrieved_at': '2015-10-19T09:08:00+00:00',
#       'url': 'https://rjsc.gov.ns.ca/rjsc/'},
#      'updated_at': '2015-10-29T18:20:30+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': 'Q08709',
#      'company_type': 'Declaration of Registered Agent',
#      'created_at': '2012-04-04T06:37:40+00:00',
#      'current_status': 'Inactive',
#      'dissolution_date': None,
#      'inactive': True,
#      'incorporation_date': '1985-03-13',
#      'jurisdiction_code': 'us_fl',
#      'name': 'BARCLAYS BANK OF NEW YORK',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/us_fl/Q08709',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2015-06-01T00:00:00+00:00',
#      'source': {'publisher': 'Florida Department of State Division of Corporations',
#       'retrieved_at': '2015-06-01T00:00:00+00:00',
#       'url': 'http://www.sunbiz.org'},
#      'updated_at': '2015-06-25T05:49:16+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '22399',
#      'company_type': 'Limited Company',
#      'created_at': '2014-06-01T05:05:25+00:00',
#      'current_status': 'Registered',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '1990-10-24',
#      'jurisdiction_code': 'ug',
#      'name': 'BARCLAYS BANK OF UGANDA (NOMINEES) LTD',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ug/22399',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-28T00:27:49+00:00',
#      'source': {'publisher': 'Uganda Registration Services Bureau ',
#       'retrieved_at': '2016-11-28T00:27:49+00:00',
#       'url': 'http://www.ursb.go.ug/'},
#      'updated_at': '2016-11-29T17:26:48+00:00'}},
#    {'company': {'branch_status': None,
#      'company_number': '4227',
#      'company_type': 'Limited Company',
#      'created_at': '2014-06-01T05:05:25+00:00',
#      'current_status': 'Registered',
#      'dissolution_date': None,
#      'inactive': False,
#      'incorporation_date': '1969-10-13',
#      'jurisdiction_code': 'ug',
#      'name': 'BARCLAYS BANK OF UGANDA LTD',
#      'native_company_number': None,
#      'opencorporates_url': 'https://opencorporates.com/companies/ug/4227',
#      'previous_names': [],
#      'registered_address': None,
#      'registered_address_in_full': None,
#      'registry_url': None,
#      'restricted_for_marketing': None,
#      'retrieved_at': '2016-11-28T00:27:49+00:00',
#      'source': {'publisher': 'Uganda Registration Services Bureau ',
#       'retrieved_at': '2016-11-28T00:27:49+00:00',
#       'url': 'http://www.ursb.go.ug/'},
#      'updated_at': '2016-11-29T17:26:26+00:00'}}],
#   'page': 1,
#   'per_page': 30,
#   'total_count': 118,
#   'total_pages': 4}}

# %%
# %store page.text > barclay_banks.txt
# Out:
# Writing 'page.text' (str) to file 'barclay_banks.txt'.

# %%
# !cat barclay_banks.txt
# Out:
# {"api_version":"0.4","results":{"companies":[{"company":{"name":"BARCLAYS BANK","company_number":"0870373575","jurisdiction_code":"be","incorporation_date":"2004-12-03","dissolution_date":null,"company_type":"Entreprise \u00e9trang\u00e8re","registry_url":"https://kbopub.economie.fgov.be/kbopub/toonondernemingps.html?lang=fr&ondernemingsnummer=0870373575","branch_status":"branch of an out-of-jurisdiction company","inactive":false,"current_status":"Soci\u00e9t\u00e9 En Nom Collectif","created_at":"2014-06-08T23:43:37+00:00","updated_at":"2016-12-15T22:59:29+00:00","retrieved_at":"2016-12-02T00:00:00+00:00","opencorporates_url":"https://opencorporates.com/companies/be/0870373575","previous_names":[],"source":{"publisher":"La Banque-Carrefour des Entreprises","url":"http://economie.fgov.be/fr/entreprises/bce/pub/opendata/","retrieved_at":"2016-12-02T00:00:00+00:00"},"registered_address":{"street_address":"LOMBARD STREET 54","locality":"LONDON","region":null,"postal_code":"EC3P 3AM","country":"Grande-Bretagne"},"registered_address_in_full":"LOMBARD STREET 54, LONDON, EC3P 3AM","restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK","company_number":"PR34","jurisdiction_code":"mt","incorporation_date":"2005-04-28","dissolution_date":null,"company_type":null,"registry_url":null,"branch_status":null,"inactive":null,"current_status":null,"created_at":"2011-05-05T01:45:46+00:00","updated_at":"2016-12-30T13:26:34+00:00","retrieved_at":"2016-12-27T20:05:04+00:00","opencorporates_url":"https://opencorporates.com/companies/mt/PR34","previous_names":[],"source":{"publisher":"The Malta Financial Services Authority","url":"http://rocsupport.mfsa.com.mt/","retrieved_at":"2016-12-27T20:05:04+00:00"},"registered_address":{"street_address":"31 Regent House Bisazza Street","locality":null,"region":null,"postal_code":null,"country":"Malta"},"registered_address_in_full":"31 Regent House Bisazza Street","restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK ( DOMINION COLONIAL AND OVERSSEAS)","company_number":"ARC35A","jurisdiction_code":"ug","incorporation_date":null,"dissolution_date":null,"company_type":"Archives","registry_url":null,"branch_status":null,"inactive":false,"current_status":"Registered","created_at":"2014-06-01T07:12:13+00:00","updated_at":"2016-11-29T17:26:57+00:00","retrieved_at":"2016-11-28T00:27:49+00:00","opencorporates_url":"https://opencorporates.com/companies/ug/ARC35A","previous_names":[],"source":{"publisher":"Uganda Registration Services Bureau ","url":"http://www.ursb.go.ug/","retrieved_at":"2016-11-28T00:27:49+00:00"},"registered_address":null,"registered_address_in_full":null,"restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK (HONG KONG NOMINEES) LIMITED","company_number":"0040910","jurisdiction_code":"hk","incorporation_date":"1974-11-26","dissolution_date":null,"company_type":"Private company limited by shares","registry_url":null,"branch_status":null,"inactive":false,"current_status":"Live","created_at":"2014-08-31T23:41:42+00:00","updated_at":"2016-08-20T14:10:17+00:00","retrieved_at":"2016-08-19T19:45:15+00:00","opencorporates_url":"https://opencorporates.com/companies/hk/0040910","previous_names":[{"start_date":"1974-11-26","company_name":"BARCLAYS BANK (HONG KONG NOMINEES) LIMITED"}],"source":{"publisher":"Hong Kong Companies Registry","url":"http://www.icris.cr.gov.hk/","retrieved_at":"2016-08-19T19:45:15+00:00"},"registered_address":null,"registered_address_in_full":null,"restricted_for_marketing":null,"native_company_number":null}},{"company":{"name":"BARCLAYS BANK (LONDON AND INTERNATIONAL) LIMITED","company_number":"00747985","jurisdiction_code":"gb","incorporation_date":"1963-01-24","dissolution_date":"2008-05-13","company_type":"Private Limited Company","registry_url":"https://beta.companieshouse.gov.uk/company/00747985","branch_status":null,"inactive":true,"current_status":"Dis ...

# %%
data = json.loads(page.text)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['api_version', 'results'])

# %%
data['results']
# Out:
# {'companies': [{'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '0870373575',
#     'company_type': 'Entreprise étrangère',
#     'created_at': '2014-06-08T23:43:37+00:00',
#     'current_status': 'Société En Nom Collectif',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '2004-12-03',
#     'jurisdiction_code': 'be',
#     'name': 'BARCLAYS BANK',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/be/0870373575',
#     'previous_names': [],
#     'registered_address': {'country': 'Grande-Bretagne',
#      'locality': 'LONDON',
#      'postal_code': 'EC3P 3AM',
#      'region': None,
#      'street_address': 'LOMBARD STREET 54'},
#     'registered_address_in_full': 'LOMBARD STREET 54, LONDON, EC3P 3AM',
#     'registry_url': 'https://kbopub.economie.fgov.be/kbopub/toonondernemingps.html?lang=fr&ondernemingsnummer=0870373575',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-12-02T00:00:00+00:00',
#     'source': {'publisher': 'La Banque-Carrefour des Entreprises',
#      'retrieved_at': '2016-12-02T00:00:00+00:00',
#      'url': 'http://economie.fgov.be/fr/entreprises/bce/pub/opendata/'},
#     'updated_at': '2016-12-15T22:59:29+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': 'PR34',
#     'company_type': None,
#     'created_at': '2011-05-05T01:45:46+00:00',
#     'current_status': None,
#     'dissolution_date': None,
#     'inactive': None,
#     'incorporation_date': '2005-04-28',
#     'jurisdiction_code': 'mt',
#     'name': 'BARCLAYS BANK',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/mt/PR34',
#     'previous_names': [],
#     'registered_address': {'country': 'Malta',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '31 Regent House Bisazza Street'},
#     'registered_address_in_full': '31 Regent House Bisazza Street',
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-12-27T20:05:04+00:00',
#     'source': {'publisher': 'The Malta Financial Services Authority',
#      'retrieved_at': '2016-12-27T20:05:04+00:00',
#      'url': 'http://rocsupport.mfsa.com.mt/'},
#     'updated_at': '2016-12-30T13:26:34+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': 'ARC35A',
#     'company_type': 'Archives',
#     'created_at': '2014-06-01T07:12:13+00:00',
#     'current_status': 'Registered',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': None,
#     'jurisdiction_code': 'ug',
#     'name': 'BARCLAYS BANK ( DOMINION COLONIAL AND OVERSSEAS)',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ug/ARC35A',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-28T00:27:49+00:00',
#     'source': {'publisher': 'Uganda Registration Services Bureau ',
#      'retrieved_at': '2016-11-28T00:27:49+00:00',
#      'url': 'http://www.ursb.go.ug/'},
#     'updated_at': '2016-11-29T17:26:57+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '0040910',
#     'company_type': 'Private company limited by shares',
#     'created_at': '2014-08-31T23:41:42+00:00',
#     'current_status': 'Live',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '1974-11-26',
#     'jurisdiction_code': 'hk',
#     'name': 'BARCLAYS BANK (HONG KONG NOMINEES) LIMITED',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/hk/0040910',
#     'previous_names': [{'company_name': 'BARCLAYS BANK (HONG KONG NOMINEES) LIMITED',
#       'start_date': '1974-11-26'}],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-08-19T19:45:15+00:00',
#     'source': {'publisher': 'Hong Kong Companies Registry',
#      'retrieved_at': '2016-08-19T19:45:15+00:00',
#      'url': 'http://www.icris.cr.gov.hk/'},
#     'updated_at': '2016-08-20T14:10:17+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '00747985',
#     'company_type': 'Private Limited Company',
#     'created_at': '2010-10-21T16:36:19+00:00',
#     'current_status': 'Dissolved',
#     'dissolution_date': '2008-05-13',
#     'inactive': True,
#     'incorporation_date': '1963-01-24',
#     'jurisdiction_code': 'gb',
#     'name': 'BARCLAYS BANK (LONDON AND INTERNATIONAL) LIMITED',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/gb/00747985',
#     'previous_names': [],
#     'registered_address': {'country': 'United Kingdom',
#      'locality': 'LONDON',
#      'postal_code': 'EC3P 3AH',
#      'region': None,
#      'street_address': '54 LOMBARD STREET'},
#     'registered_address_in_full': '54 LOMBARD STREET, LONDON, EC3P 3AH',
#     'registry_url': 'https://beta.companieshouse.gov.uk/company/00747985',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2015-03-14T00:00:53+00:00',
#     'source': {'publisher': 'UK Companies House',
#      'retrieved_at': '2015-03-14T00:00:53+00:00',
#      'terms': 'UK Crown Copyright',
#      'url': 'http://xmlgw.companieshouse.gov.uk/'},
#     'updated_at': '2015-12-13T12:49:26+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '198003638Z',
#     'company_type': None,
#     'created_at': '2011-04-13T11:48:37+00:00',
#     'current_status': 'Live Company',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': None,
#     'jurisdiction_code': 'sg',
#     'name': 'BARCLAYS BANK (SINGAPORE NOMINEES) PTE LTD',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/sg/198003638Z',
#     'previous_names': [],
#     'registered_address': {'country': 'Singapore',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)'},
#     'registered_address_in_full': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)',
#     'registry_url': 'https://www.tis.bizfile.gov.sg/ngbtisinternet/faces/oracle/webcenter/portalapp/pages/productlisting/ishopProductListing.jspx?EntityNo=198003638Z&_afrLoop=356552297613828&_afrWindowMode=0&_afrWindowId=null',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-23T03:56:51+00:00',
#     'source': {'publisher': 'Singapore Accounting and Corporate Regulatory Authority',
#      'retrieved_at': '2016-11-23T03:56:51+00:00',
#      'url': 'http://www.bizfile.gov.sg'},
#     'updated_at': '2016-11-30T16:43:37+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '199205730M',
#     'company_type': None,
#     'created_at': '2011-04-13T11:48:37+00:00',
#     'current_status': 'Live Company',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': None,
#     'jurisdiction_code': 'sg',
#     'name': 'BARCLAYS BANK (SOUTH EAST ASIA) NOMINEES PTE LTD',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/sg/199205730M',
#     'previous_names': [],
#     'registered_address': {'country': 'Singapore',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)'},
#     'registered_address_in_full': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)',
#     'registry_url': 'https://www.tis.bizfile.gov.sg/ngbtisinternet/faces/oracle/webcenter/portalapp/pages/productlisting/ishopProductListing.jspx?EntityNo=199205730M&_afrLoop=288507653680897&_afrWindowMode=0&_afrWindowId=null',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-21T18:13:11+00:00',
#     'source': {'publisher': 'Singapore Accounting and Corporate Regulatory Authority',
#      'retrieved_at': '2016-11-21T18:13:11+00:00',
#      'url': 'http://www.bizfile.gov.sg'},
#     'updated_at': '2016-11-30T19:58:50+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '2162687',
#     'company_type': 'Non-distributing corporation with 50 or fewer shareholders',
#     'created_at': '2011-06-03T18:45:19+00:00',
#     'current_status': 'Inactive   Amalgamated',
#     'dissolution_date': '1992-11-01',
#     'inactive': True,
#     'incorporation_date': '1987-03-02',
#     'jurisdiction_code': 'ca',
#     'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ca/2162687',
#     'previous_names': [{'company_name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#       'end_date': '1989-05-26T00:00:00',
#       'start_date': '1987-03-02T00:00:00'},
#      {'company_name': 'CORPORATION FINANCIERE AGRICULTURELLE DE LA BANQUE BARCLAYS',
#       'end_date': '1989-05-26T00:00:00',
#       'start_date': '1987-03-02T00:00:00'}],
#     'registered_address': {'country': 'CA',
#      'locality': 'CALGARY',
#      'postal_code': 'T2P3S8',
#      'region': 'AB',
#      'street_address': '530  8TH AVENUE S.W.\nSUITE 2120'},
#     'registered_address_in_full': '530  8TH AVENUE S.W.\nSUITE 2120, CALGARY, AB, T2P3S8',
#     'registry_url': 'https://www.ic.gc.ca/app/scr/cc/CorporationsCanada/fdrlCrpDtls.html?corpId=2162687',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-04-17T17:51:34+00:00',
#     'source': {'publisher': 'Corporations Canada',
#      'retrieved_at': '2016-04-17T17:51:34+00:00',
#      'url': 'https://www.ic.gc.ca/app/scr/cc/CorporationsCanada/fdrlCrpDtls.html?corpId=2162687'},
#     'updated_at': '2016-07-15T22:22:15+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '1603D',
#     'company_type': 'Company - With Share Capital - Dominion',
#     'created_at': '2014-10-27T23:46:25+00:00',
#     'current_status': 'Cancelled   Voluntary',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': '1987-03-06',
#     'jurisdiction_code': 'ca_nl',
#     'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ca_nl/1603D',
#     'previous_names': [],
#     'registered_address': {'country': 'Canada',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': "O'REILLY,NOSEWORTHY, 323, DUCKWORTH ST,ST JOHN'S,NF"},
#     'registered_address_in_full': "O'REILLY,NOSEWORTHY, 323, DUCKWORTH ST,ST JOHN'S,NF",
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-12-12T01:09:37+00:00',
#     'source': {'publisher': 'Government of Newfoundland & Labrador Registry of Companies',
#      'retrieved_at': '2016-12-12T01:09:37+00:00',
#      'url': 'https://cado.eservices.gov.nl.ca'},
#     'updated_at': '2016-12-15T21:21:09+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '1765413',
#     'company_type': 'Extra-Provincial Financial Institution',
#     'created_at': '2012-09-27T09:00:24+00:00',
#     'current_status': 'Revoked By Request',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': '1987-03-06',
#     'jurisdiction_code': 'ca_ns',
#     'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ca_ns/1765413',
#     'previous_names': [],
#     'registered_address': {'country': 'Canada',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': 'STE. 2120, 530-8TH AVENUE S.W.\nCALGARY AB Canada T2P3S8'},
#     'registered_address_in_full': 'STE. 2120, 530-8TH AVENUE S.W.\nCALGARY AB Canada T2P3S8',
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2015-10-17T05:35:56+00:00',
#     'source': {'publisher': 'Nova Scotia Registry of Joint Stock Companies',
#      'retrieved_at': '2015-10-17T05:35:56+00:00',
#      'url': 'https://rjsc.gov.ns.ca/rjsc/'},
#     'updated_at': '2016-06-23T14:42:41+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '70805',
#     'company_type': None,
#     'created_at': '2014-11-08T22:48:32+00:00',
#     'current_status': 'F',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': None,
#     'jurisdiction_code': 'ca_nb',
#     'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION CORPORATION FINANCIERE AGRICULTURELLE DE LA BANQUE BARCLAYS',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ca_nb/70805',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2017-01-07T05:25:06+00:00',
#     'source': {'publisher': 'New Brunswick Corporate Affairs Registry Database',
#      'retrieved_at': '2017-01-07T05:25:06+00:00',
#      'url': 'https://www.pxw2.snb.ca/card_online/Search/search.aspx'},
#     'updated_at': '2017-01-07T15:07:56+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '11412-1',
#     'company_type': 'Foreign Branches Company',
#     'created_at': '2013-03-19T04:01:31+00:00',
#     'current_status': 'Deleted Without Payment',
#     'dissolution_date': '1992-06-10',
#     'inactive': True,
#     'incorporation_date': '1981-10-06',
#     'jurisdiction_code': 'bh',
#     'name': 'BARCLAYS BANK B.L.C',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/bh/11412-1',
#     'previous_names': [],
#     'registered_address': {'country': 'Bahrain',
#      'locality': "MANAMA/DIPL'AREA",
#      'postal_code': None,
#      'region': None,
#      'street_address': 'Flat 31, Building 419, Road 1705, Block 317'},
#     'registered_address_in_full': "Flat 31, Building 419, Road 1705, Block 317, MANAMA/DIPL'AREA",
#     'registry_url': "http://www.moic.gov.bh/CReServices/inquiry/javascript:__doPostBack('grdCR$ctl07$lnkCrBr','')",
#     'restricted_for_marketing': None,
#     'retrieved_at': '2014-04-09T18:41:49+00:00',
#     'source': {'publisher': 'Bahrain Ministry Of Industry And Commerce',
#      'retrieved_at': '2014-04-09T18:41:49+00:00',
#      'url': "http://www.moic.gov.bh/CReServices/inquiry/javascript:__doPostBack('grdCR$ctl07$lnkCrBr','')"},
#     'updated_at': '2014-04-09T23:48:04+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': 'F14031579',
#     'company_type': None,
#     'created_at': '2012-03-03T07:07:39+00:00',
#     'current_status': 'Incorporated',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '2011-03-24',
#     'jurisdiction_code': 'us_md',
#     'name': 'BARCLAYS BANK DELAWARE',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_md/F14031579',
#     'previous_names': [],
#     'registered_address': {'country': 'United States',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '100 S WEST ST\nWILMINGTON, DE 19801'},
#     'registered_address_in_full': '100 S WEST ST\nWILMINGTON, DE 19801',
#     'registry_url': 'http://sdatcert3.resiusa.org/UCC-Charter/Pages/CharterSearch/default.aspx',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-09-04T17:59:47+00:00',
#     'source': {'publisher': 'Maryland Department of Assessments & Taxation',
#      'retrieved_at': '2016-09-04T17:59:47+00:00',
#      'url': 'http://sdat.dat.maryland.gov/ucc-charter/Pages/CharterSearch/default.aspx'},
#     'updated_at': '2016-10-05T02:54:57+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '3227623',
#     'company_type': 'Corporation',
#     'created_at': '2015-10-15T00:29:27+00:00',
#     'current_status': None,
#     'dissolution_date': None,
#     'inactive': None,
#     'incorporation_date': '2001-03-21',
#     'jurisdiction_code': 'us_de',
#     'name': 'BARCLAYS BANK DELAWARE',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_de/3227623',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-07-21T02:35:45+00:00',
#     'source': {'publisher': 'Delaware Department of State: Division of Corporations',
#      'retrieved_at': '2016-07-21T02:35:45+00:00',
#      'url': 'http://www.corp.delaware.gov/'},
#     'updated_at': '2016-10-05T02:54:58+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': 'EXTUID_3204',
#     'company_type': 'RC - Registered Private Company',
#     'created_at': '2010-11-19T03:37:24+00:00',
#     'current_status': 'Dissolved',
#     'dissolution_date': '2003-05-28',
#     'inactive': True,
#     'incorporation_date': '1969-01-09',
#     'jurisdiction_code': 'je',
#     'name': 'BARCLAYS BANK FINANCE COMPANY (JERSEY) LIMITED',
#     'native_company_number': '3564',
#     'opencorporates_url': 'https://opencorporates.com/companies/je/EXTUID_3204',
#     'previous_names': [],
#     'registered_address': {'country': None,
#      'locality': 'St Helier',
#      'postal_code': None,
#      'region': None,
#      'street_address': '29/31 The Esplanade'},
#     'registered_address_in_full': '29/31 The Esplanade, St Helier',
#     'registry_url': 'https://www.jerseyfsc.org/registry/documentsearch/NameDetail.aspx?id=3204',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-22T23:16:27+00:00',
#     'source': {'publisher': 'Jersey Financial Services Commission',
#      'retrieved_at': '2016-11-22T23:16:27+00:00',
#      'url': 'https://www.jerseyfsc.org/registry/documentsearch/NameDetail.aspx?id=3204'},
#     'updated_at': '2016-11-23T00:18:49+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '10208960',
#     'company_type': 'Foreign Corp',
#     'created_at': '2016-01-23T00:54:09+00:00',
#     'current_status': 'Active',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '2015-05-13',
#     'jurisdiction_code': 'us_ne',
#     'name': 'BARCLAYS BANK INC',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_ne/10208960',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': 'https://www.nebraska.gov/sos/corp/corpsearch.cgi?acct-number=10208960',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-01-19T13:08:58+00:00',
#     'source': {'publisher': 'Nebraska Secretary of State',
#      'retrieved_at': '2016-01-19T13:08:58+00:00',
#      'url': 'https://www.nebraska.gov/sos/corp/corpsearch.cgi?acct-number=10208960'},
#     'updated_at': '2016-01-23T02:34:16+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': 'F001323223',
#     'company_type': 'Gen. Business - For Profit',
#     'created_at': '2016-02-21T02:23:16+00:00',
#     'current_status': 'Good Standing',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '2015-09-04',
#     'jurisdiction_code': 'us_mo',
#     'name': 'BARCLAYS BANK INC.',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_mo/F001323223',
#     'previous_names': [],
#     'registered_address': {'country': 'United States',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '120 South Central Ave\nClayton, MO 63105'},
#     'registered_address_in_full': '120 South Central Ave\nClayton, MO 63105',
#     'registry_url': 'https://bsd.sos.mo.gov/BusinessEntity/BusinessEntityDetail.aspx?page=beSearch&ID=3746202',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-08-04T03:18:35+00:00',
#     'source': {'publisher': 'Missouri Secretary of State',
#      'retrieved_at': '2016-08-04T03:18:35+00:00',
#      'url': 'https://bsd.sos.mo.gov/BusinessEntity/BusinessEntityDetail.aspx?page=beSearch&ID=3746202'},
#     'updated_at': '2016-08-08T14:11:18+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '0324949',
#     'company_type': 'Foreign Profit Corporation',
#     'created_at': '2016-12-01T04:14:54+00:00',
#     'current_status': 'Active',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '2016-11-28',
#     'jurisdiction_code': 'us_vt',
#     'name': 'BARCLAYS BANK INC.',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_vt/0324949',
#     'previous_names': [],
#     'registered_address': {'country': 'United States',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '1 Churchill Place, London, E145H, GBR'},
#     'registered_address_in_full': '1 Churchill Place, London, E145H, GBR',
#     'registry_url': 'https://www.vtsosonline.com/online/BusinessInquire/BusinessInformation?businessID=0324949',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2017-01-09T03:30:44+00:00',
#     'source': {'publisher': 'Vermont Secretary of State: Corporations Division',
#      'retrieved_at': '2017-01-09T03:30:44+00:00',
#      'url': 'http://www.sec.state.vt.us/corps/corp.htm'},
#     'updated_at': '2017-01-09T13:27:17+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '01048020',
#     'company_type': 'Private Limited Company',
#     'created_at': '2011-04-25T10:43:36+00:00',
#     'current_status': 'Dissolved',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': '1972-03-30',
#     'jurisdiction_code': 'gb',
#     'name': 'BARCLAYS BANK INTERNATIONAL INVESTMENTS HOLDINGS LIMITED',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/gb/01048020',
#     'previous_names': [],
#     'registered_address': {'country': 'United Kingdom',
#      'locality': 'LONDON',
#      'postal_code': 'EC4A 3TR',
#      'region': None,
#      'street_address': 'HILL HOUSE, 1 LITTLE NEW STREET'},
#     'registered_address_in_full': 'HILL HOUSE, 1 LITTLE NEW STREET, LONDON, EC4A 3TR',
#     'registry_url': 'https://beta.companieshouse.gov.uk/company/01048020',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2011-05-03T05:36:17+00:00',
#     'source': {'publisher': 'UK Companies House',
#      'retrieved_at': '2011-05-03T05:36:17+00:00',
#      'terms': 'UK Crown Copyright',
#      'url': 'http://xmlgw.companieshouse.gov.uk/'},
#     'updated_at': '2015-12-13T23:57:59+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '49396015',
#     'company_type': 'Anden udenlandsk virksomhed',
#     'created_at': '2016-01-01T21:07:17+00:00',
#     'current_status': None,
#     'dissolution_date': '1989-12-31',
#     'inactive': True,
#     'incorporation_date': '1974-09-20',
#     'jurisdiction_code': 'dk',
#     'name': 'BARCLAYS BANK INTERNATIONAL LTD',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/dk/49396015',
#     'previous_names': [{'company_name': 'BARCLAYS BANK INTERNATIONAL LTD',
#       'end_date': '1989-12-31',
#       'start_date': '1974-09-20'}],
#     'registered_address': {'country': 'Denmark',
#      'locality': 'København K',
#      'postal_code': '1061',
#      'region': None,
#      'street_address': 'Ved Stranden 8'},
#     'registered_address_in_full': 'Ved Stranden 8, København K, 1061',
#     'registry_url': 'http://datacvr.virk.dk/data/visenhed?enhedstype=virksomhed&id=49396015',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2017-01-02T01:09:15+00:00',
#     'source': {'publisher': 'Det centrale virksomhedsregister',
#      'retrieved_at': '2017-01-02T01:09:15+00:00',
#      'terms': 'Vilkår for brug af danske offentlige data/CVR.dk licence',
#      'terms_url': 'http://www.cvr.dk/Site/Forms/CMS/DisplayPage.aspx?pageid=91',
#      'url': 'http://datacvr.virk.dk/data/'},
#     'updated_at': '2017-01-12T01:05:35+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '1678',
#     'company_type': 'Private',
#     'created_at': '2011-07-25T05:32:46+00:00',
#     'current_status': 'Dissolved',
#     'dissolution_date': '1992-10-16',
#     'inactive': True,
#     'incorporation_date': '1893-08-15',
#     'jurisdiction_code': 'ie',
#     'name': 'BARCLAYS BANK IRELAND LIMITED',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ie/1678',
#     'previous_names': [],
#     'registered_address': {'country': 'Ireland',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': "47/49, ST. STEPHEN'S GREEN, DUBLIN 2."},
#     'registered_address_in_full': "47/49, ST. STEPHEN'S GREEN, DUBLIN 2.",
#     'registry_url': 'http://www.cro.ie/search/CompanyDetails.aspx?id=1678&type=C',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-29T13:11:45+00:00',
#     'source': {'publisher': 'Ireland Companies Registration Office',
#      'retrieved_at': '2016-11-29T13:11:45+00:00',
#      'terms': 'CRO Open Services licence',
#      'url': 'https://services.cro.ie/'},
#     'updated_at': '2016-11-29T13:11:45+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '396330',
#     'company_type': 'PLC - Public Limited Company',
#     'created_at': '2011-07-25T05:32:46+00:00',
#     'current_status': 'Normal',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '2005-01-12',
#     'jurisdiction_code': 'ie',
#     'name': 'BARCLAYS BANK IRELAND PUBLIC LIMITED COMPANY',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ie/396330',
#     'previous_names': [],
#     'registered_address': {'country': 'Ireland',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': 'TWO PARK PLACE, HATCH STREET, DUBLIN 2.'},
#     'registered_address_in_full': 'TWO PARK PLACE, HATCH STREET, DUBLIN 2.',
#     'registry_url': 'http://www.cro.ie/search/CompanyDetails.aspx?id=396330&type=C',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2017-01-03T00:38:31+00:00',
#     'source': {'publisher': 'Ireland Companies Registration Office',
#      'retrieved_at': '2017-01-03T00:38:31+00:00',
#      'terms': 'CRO Open Services licence',
#      'url': 'https://services.cro.ie/'},
#     'updated_at': '2017-01-03T00:38:31+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': 'Z13536230',
#     'company_type': None,
#     'created_at': '2012-03-03T07:07:40+00:00',
#     'current_status': 'Revived',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '2010-04-22',
#     'jurisdiction_code': 'us_md',
#     'name': 'BARCLAYS BANK LC A/K/A BARCLAYS BANK PLC',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_md/Z13536230',
#     'previous_names': [],
#     'registered_address': {'country': 'United States',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '1 CHURCHILL PL\nLONDON,'},
#     'registered_address_in_full': '1 CHURCHILL PL\nLONDON,',
#     'registry_url': 'http://sdatcert3.resiusa.org/UCC-Charter/Pages/CharterSearch/default.aspx',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-09-12T00:41:34+00:00',
#     'source': {'publisher': 'Maryland Department of Assessments & Taxation',
#      'retrieved_at': '2016-09-12T00:41:34+00:00',
#      'url': 'http://sdat.dat.maryland.gov/ucc-charter/Pages/CharterSearch/default.aspx'},
#     'updated_at': '2016-10-08T01:17:02+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '0726501',
#     'company_type': 'Foreign Corporation',
#     'created_at': '2015-06-22T20:51:03+00:00',
#     'current_status': 'I   Inactive',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': None,
#     'jurisdiction_code': 'us_ky',
#     'name': 'BARCLAYS BANK LIMITED',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_ky/0726501',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': 'https://app.sos.ky.gov/ftshow/(S(4g2sxj3uxdikdps4zvp2qtdl))/default.aspx?path=ftsearch&id=0726501&ct=09&cs=99999',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-10-12T06:34:44+00:00',
#     'source': {'publisher': 'Kentucky Secretary Of State',
#      'retrieved_at': '2016-10-12T06:34:44+00:00',
#      'url': 'https://app.sos.ky.gov/ftshow/(S(4g2sxj3uxdikdps4zvp2qtdl))/default.aspx?path=ftsearch&id=0726501&ct=09&cs=99999'},
#     'updated_at': '2016-10-25T02:26:57+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '0677543',
#     'company_type': 'Foreign Corporation',
#     'created_at': '2015-06-22T15:01:32+00:00',
#     'current_status': 'I   Inactive',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': None,
#     'jurisdiction_code': 'us_ky',
#     'name': 'BARCLAYS BANK LIMTED',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_ky/0677543',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': 'https://app.sos.ky.gov/ftshow/(S(1b2xjuppwki5twd4l5b14itt))/default.aspx?path=ftsearch&id=0677543&ct=09&cs=99999',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-10-06T08:08:31+00:00',
#     'source': {'publisher': 'Kentucky Secretary Of State',
#      'retrieved_at': '2016-10-06T08:08:31+00:00',
#      'url': 'https://app.sos.ky.gov/ftshow/(S(1b2xjuppwki5twd4l5b14itt))/default.aspx?path=ftsearch&id=0677543&ct=09&cs=99999'},
#     'updated_at': '2016-10-09T13:49:57+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': 'C0489490',
#     'company_type': 'Domestic Stock',
#     'created_at': '2011-09-14T21:24:05+00:00',
#     'current_status': 'Merged Out',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': '1965-04-20',
#     'jurisdiction_code': 'us_ca',
#     'name': 'BARCLAYS BANK OF CALIFORNIA',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_ca/C0489490',
#     'previous_names': [],
#     'registered_address': {'country': 'United States',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '111 PINE STREET STE. 200,\nSAN FRANCISCO, CA 94111'},
#     'registered_address_in_full': '111 PINE STREET STE. 200,\nSAN FRANCISCO, CA 94111',
#     'registry_url': 'https://businessfilings.sos.ca.gov/frmDetail.asp?CorpID=00489490',
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-24T08:22:47+00:00',
#     'source': {'publisher': 'California Secretary of State',
#      'retrieved_at': '2016-11-24T08:22:47+00:00',
#      'url': 'https://businessfilings.sos.ca.gov/frmDetail.asp?CorpID=00489490'},
#     'updated_at': '2016-12-10T20:59:16+00:00'}},
#   {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#     'company_number': '1956986',
#     'company_type': 'Extra-Provincial Financial Institution',
#     'created_at': '2012-09-27T01:51:12+00:00',
#     'current_status': 'Revoked By Request',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': '1989-06-01',
#     'jurisdiction_code': 'ca_ns',
#     'name': 'BARCLAYS BANK OF CANADA',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ca_ns/1956986',
#     'previous_names': [],
#     'registered_address': {'country': 'Canada',
#      'locality': None,
#      'postal_code': None,
#      'region': None,
#      'street_address': '304 BAY ST\nTORONTO ON Canada M5H2P2'},
#     'registered_address_in_full': '304 BAY ST\nTORONTO ON Canada M5H2P2',
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2015-10-19T09:08:00+00:00',
#     'source': {'publisher': 'Nova Scotia Registry of Joint Stock Companies',
#      'retrieved_at': '2015-10-19T09:08:00+00:00',
#      'url': 'https://rjsc.gov.ns.ca/rjsc/'},
#     'updated_at': '2015-10-29T18:20:30+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': 'Q08709',
#     'company_type': 'Declaration of Registered Agent',
#     'created_at': '2012-04-04T06:37:40+00:00',
#     'current_status': 'Inactive',
#     'dissolution_date': None,
#     'inactive': True,
#     'incorporation_date': '1985-03-13',
#     'jurisdiction_code': 'us_fl',
#     'name': 'BARCLAYS BANK OF NEW YORK',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/us_fl/Q08709',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2015-06-01T00:00:00+00:00',
#     'source': {'publisher': 'Florida Department of State Division of Corporations',
#      'retrieved_at': '2015-06-01T00:00:00+00:00',
#      'url': 'http://www.sunbiz.org'},
#     'updated_at': '2015-06-25T05:49:16+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '22399',
#     'company_type': 'Limited Company',
#     'created_at': '2014-06-01T05:05:25+00:00',
#     'current_status': 'Registered',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '1990-10-24',
#     'jurisdiction_code': 'ug',
#     'name': 'BARCLAYS BANK OF UGANDA (NOMINEES) LTD',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ug/22399',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-28T00:27:49+00:00',
#     'source': {'publisher': 'Uganda Registration Services Bureau ',
#      'retrieved_at': '2016-11-28T00:27:49+00:00',
#      'url': 'http://www.ursb.go.ug/'},
#     'updated_at': '2016-11-29T17:26:48+00:00'}},
#   {'company': {'branch_status': None,
#     'company_number': '4227',
#     'company_type': 'Limited Company',
#     'created_at': '2014-06-01T05:05:25+00:00',
#     'current_status': 'Registered',
#     'dissolution_date': None,
#     'inactive': False,
#     'incorporation_date': '1969-10-13',
#     'jurisdiction_code': 'ug',
#     'name': 'BARCLAYS BANK OF UGANDA LTD',
#     'native_company_number': None,
#     'opencorporates_url': 'https://opencorporates.com/companies/ug/4227',
#     'previous_names': [],
#     'registered_address': None,
#     'registered_address_in_full': None,
#     'registry_url': None,
#     'restricted_for_marketing': None,
#     'retrieved_at': '2016-11-28T00:27:49+00:00',
#     'source': {'publisher': 'Uganda Registration Services Bureau ',
#      'retrieved_at': '2016-11-28T00:27:49+00:00',
#      'url': 'http://www.ursb.go.ug/'},
#     'updated_at': '2016-11-29T17:26:26+00:00'}}],
#  'page': 1,
#  'per_page': 30,
#  'total_count': 118,
#  'total_pages': 4}

# %%
data['results'].keys()
# Out:
# dict_keys(['total_count', 'companies', 'page', 'per_page', 'total_pages'])

# %%
data['results']['companies']
# Out:
# [{'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '0870373575',
#    'company_type': 'Entreprise étrangère',
#    'created_at': '2014-06-08T23:43:37+00:00',
#    'current_status': 'Société En Nom Collectif',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '2004-12-03',
#    'jurisdiction_code': 'be',
#    'name': 'BARCLAYS BANK',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/be/0870373575',
#    'previous_names': [],
#    'registered_address': {'country': 'Grande-Bretagne',
#     'locality': 'LONDON',
#     'postal_code': 'EC3P 3AM',
#     'region': None,
#     'street_address': 'LOMBARD STREET 54'},
#    'registered_address_in_full': 'LOMBARD STREET 54, LONDON, EC3P 3AM',
#    'registry_url': 'https://kbopub.economie.fgov.be/kbopub/toonondernemingps.html?lang=fr&ondernemingsnummer=0870373575',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-12-02T00:00:00+00:00',
#    'source': {'publisher': 'La Banque-Carrefour des Entreprises',
#     'retrieved_at': '2016-12-02T00:00:00+00:00',
#     'url': 'http://economie.fgov.be/fr/entreprises/bce/pub/opendata/'},
#    'updated_at': '2016-12-15T22:59:29+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': 'PR34',
#    'company_type': None,
#    'created_at': '2011-05-05T01:45:46+00:00',
#    'current_status': None,
#    'dissolution_date': None,
#    'inactive': None,
#    'incorporation_date': '2005-04-28',
#    'jurisdiction_code': 'mt',
#    'name': 'BARCLAYS BANK',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/mt/PR34',
#    'previous_names': [],
#    'registered_address': {'country': 'Malta',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '31 Regent House Bisazza Street'},
#    'registered_address_in_full': '31 Regent House Bisazza Street',
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-12-27T20:05:04+00:00',
#    'source': {'publisher': 'The Malta Financial Services Authority',
#     'retrieved_at': '2016-12-27T20:05:04+00:00',
#     'url': 'http://rocsupport.mfsa.com.mt/'},
#    'updated_at': '2016-12-30T13:26:34+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': 'ARC35A',
#    'company_type': 'Archives',
#    'created_at': '2014-06-01T07:12:13+00:00',
#    'current_status': 'Registered',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': None,
#    'jurisdiction_code': 'ug',
#    'name': 'BARCLAYS BANK ( DOMINION COLONIAL AND OVERSSEAS)',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ug/ARC35A',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-28T00:27:49+00:00',
#    'source': {'publisher': 'Uganda Registration Services Bureau ',
#     'retrieved_at': '2016-11-28T00:27:49+00:00',
#     'url': 'http://www.ursb.go.ug/'},
#    'updated_at': '2016-11-29T17:26:57+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '0040910',
#    'company_type': 'Private company limited by shares',
#    'created_at': '2014-08-31T23:41:42+00:00',
#    'current_status': 'Live',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '1974-11-26',
#    'jurisdiction_code': 'hk',
#    'name': 'BARCLAYS BANK (HONG KONG NOMINEES) LIMITED',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/hk/0040910',
#    'previous_names': [{'company_name': 'BARCLAYS BANK (HONG KONG NOMINEES) LIMITED',
#      'start_date': '1974-11-26'}],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-08-19T19:45:15+00:00',
#    'source': {'publisher': 'Hong Kong Companies Registry',
#     'retrieved_at': '2016-08-19T19:45:15+00:00',
#     'url': 'http://www.icris.cr.gov.hk/'},
#    'updated_at': '2016-08-20T14:10:17+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '00747985',
#    'company_type': 'Private Limited Company',
#    'created_at': '2010-10-21T16:36:19+00:00',
#    'current_status': 'Dissolved',
#    'dissolution_date': '2008-05-13',
#    'inactive': True,
#    'incorporation_date': '1963-01-24',
#    'jurisdiction_code': 'gb',
#    'name': 'BARCLAYS BANK (LONDON AND INTERNATIONAL) LIMITED',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/gb/00747985',
#    'previous_names': [],
#    'registered_address': {'country': 'United Kingdom',
#     'locality': 'LONDON',
#     'postal_code': 'EC3P 3AH',
#     'region': None,
#     'street_address': '54 LOMBARD STREET'},
#    'registered_address_in_full': '54 LOMBARD STREET, LONDON, EC3P 3AH',
#    'registry_url': 'https://beta.companieshouse.gov.uk/company/00747985',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2015-03-14T00:00:53+00:00',
#    'source': {'publisher': 'UK Companies House',
#     'retrieved_at': '2015-03-14T00:00:53+00:00',
#     'terms': 'UK Crown Copyright',
#     'url': 'http://xmlgw.companieshouse.gov.uk/'},
#    'updated_at': '2015-12-13T12:49:26+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '198003638Z',
#    'company_type': None,
#    'created_at': '2011-04-13T11:48:37+00:00',
#    'current_status': 'Live Company',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': None,
#    'jurisdiction_code': 'sg',
#    'name': 'BARCLAYS BANK (SINGAPORE NOMINEES) PTE LTD',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/sg/198003638Z',
#    'previous_names': [],
#    'registered_address': {'country': 'Singapore',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)'},
#    'registered_address_in_full': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)',
#    'registry_url': 'https://www.tis.bizfile.gov.sg/ngbtisinternet/faces/oracle/webcenter/portalapp/pages/productlisting/ishopProductListing.jspx?EntityNo=198003638Z&_afrLoop=356552297613828&_afrWindowMode=0&_afrWindowId=null',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-23T03:56:51+00:00',
#    'source': {'publisher': 'Singapore Accounting and Corporate Regulatory Authority',
#     'retrieved_at': '2016-11-23T03:56:51+00:00',
#     'url': 'http://www.bizfile.gov.sg'},
#    'updated_at': '2016-11-30T16:43:37+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '199205730M',
#    'company_type': None,
#    'created_at': '2011-04-13T11:48:37+00:00',
#    'current_status': 'Live Company',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': None,
#    'jurisdiction_code': 'sg',
#    'name': 'BARCLAYS BANK (SOUTH EAST ASIA) NOMINEES PTE LTD',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/sg/199205730M',
#    'previous_names': [],
#    'registered_address': {'country': 'Singapore',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)'},
#    'registered_address_in_full': '10 MARINA BOULEVARD, #24-01, MARINA BAY FINANCIAL CENTRE, SINGAPORE(018983)',
#    'registry_url': 'https://www.tis.bizfile.gov.sg/ngbtisinternet/faces/oracle/webcenter/portalapp/pages/productlisting/ishopProductListing.jspx?EntityNo=199205730M&_afrLoop=288507653680897&_afrWindowMode=0&_afrWindowId=null',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-21T18:13:11+00:00',
#    'source': {'publisher': 'Singapore Accounting and Corporate Regulatory Authority',
#     'retrieved_at': '2016-11-21T18:13:11+00:00',
#     'url': 'http://www.bizfile.gov.sg'},
#    'updated_at': '2016-11-30T19:58:50+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '2162687',
#    'company_type': 'Non-distributing corporation with 50 or fewer shareholders',
#    'created_at': '2011-06-03T18:45:19+00:00',
#    'current_status': 'Inactive   Amalgamated',
#    'dissolution_date': '1992-11-01',
#    'inactive': True,
#    'incorporation_date': '1987-03-02',
#    'jurisdiction_code': 'ca',
#    'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ca/2162687',
#    'previous_names': [{'company_name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#      'end_date': '1989-05-26T00:00:00',
#      'start_date': '1987-03-02T00:00:00'},
#     {'company_name': 'CORPORATION FINANCIERE AGRICULTURELLE DE LA BANQUE BARCLAYS',
#      'end_date': '1989-05-26T00:00:00',
#      'start_date': '1987-03-02T00:00:00'}],
#    'registered_address': {'country': 'CA',
#     'locality': 'CALGARY',
#     'postal_code': 'T2P3S8',
#     'region': 'AB',
#     'street_address': '530  8TH AVENUE S.W.\nSUITE 2120'},
#    'registered_address_in_full': '530  8TH AVENUE S.W.\nSUITE 2120, CALGARY, AB, T2P3S8',
#    'registry_url': 'https://www.ic.gc.ca/app/scr/cc/CorporationsCanada/fdrlCrpDtls.html?corpId=2162687',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-04-17T17:51:34+00:00',
#    'source': {'publisher': 'Corporations Canada',
#     'retrieved_at': '2016-04-17T17:51:34+00:00',
#     'url': 'https://www.ic.gc.ca/app/scr/cc/CorporationsCanada/fdrlCrpDtls.html?corpId=2162687'},
#    'updated_at': '2016-07-15T22:22:15+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '1603D',
#    'company_type': 'Company - With Share Capital - Dominion',
#    'created_at': '2014-10-27T23:46:25+00:00',
#    'current_status': 'Cancelled   Voluntary',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': '1987-03-06',
#    'jurisdiction_code': 'ca_nl',
#    'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ca_nl/1603D',
#    'previous_names': [],
#    'registered_address': {'country': 'Canada',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': "O'REILLY,NOSEWORTHY, 323, DUCKWORTH ST,ST JOHN'S,NF"},
#    'registered_address_in_full': "O'REILLY,NOSEWORTHY, 323, DUCKWORTH ST,ST JOHN'S,NF",
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-12-12T01:09:37+00:00',
#    'source': {'publisher': 'Government of Newfoundland & Labrador Registry of Companies',
#     'retrieved_at': '2016-12-12T01:09:37+00:00',
#     'url': 'https://cado.eservices.gov.nl.ca'},
#    'updated_at': '2016-12-15T21:21:09+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '1765413',
#    'company_type': 'Extra-Provincial Financial Institution',
#    'created_at': '2012-09-27T09:00:24+00:00',
#    'current_status': 'Revoked By Request',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': '1987-03-06',
#    'jurisdiction_code': 'ca_ns',
#    'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ca_ns/1765413',
#    'previous_names': [],
#    'registered_address': {'country': 'Canada',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': 'STE. 2120, 530-8TH AVENUE S.W.\nCALGARY AB Canada T2P3S8'},
#    'registered_address_in_full': 'STE. 2120, 530-8TH AVENUE S.W.\nCALGARY AB Canada T2P3S8',
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2015-10-17T05:35:56+00:00',
#    'source': {'publisher': 'Nova Scotia Registry of Joint Stock Companies',
#     'retrieved_at': '2015-10-17T05:35:56+00:00',
#     'url': 'https://rjsc.gov.ns.ca/rjsc/'},
#    'updated_at': '2016-06-23T14:42:41+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '70805',
#    'company_type': None,
#    'created_at': '2014-11-08T22:48:32+00:00',
#    'current_status': 'F',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': None,
#    'jurisdiction_code': 'ca_nb',
#    'name': 'BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION CORPORATION FINANCIERE AGRICULTURELLE DE LA BANQUE BARCLAYS',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ca_nb/70805',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2017-01-07T05:25:06+00:00',
#    'source': {'publisher': 'New Brunswick Corporate Affairs Registry Database',
#     'retrieved_at': '2017-01-07T05:25:06+00:00',
#     'url': 'https://www.pxw2.snb.ca/card_online/Search/search.aspx'},
#    'updated_at': '2017-01-07T15:07:56+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '11412-1',
#    'company_type': 'Foreign Branches Company',
#    'created_at': '2013-03-19T04:01:31+00:00',
#    'current_status': 'Deleted Without Payment',
#    'dissolution_date': '1992-06-10',
#    'inactive': True,
#    'incorporation_date': '1981-10-06',
#    'jurisdiction_code': 'bh',
#    'name': 'BARCLAYS BANK B.L.C',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/bh/11412-1',
#    'previous_names': [],
#    'registered_address': {'country': 'Bahrain',
#     'locality': "MANAMA/DIPL'AREA",
#     'postal_code': None,
#     'region': None,
#     'street_address': 'Flat 31, Building 419, Road 1705, Block 317'},
#    'registered_address_in_full': "Flat 31, Building 419, Road 1705, Block 317, MANAMA/DIPL'AREA",
#    'registry_url': "http://www.moic.gov.bh/CReServices/inquiry/javascript:__doPostBack('grdCR$ctl07$lnkCrBr','')",
#    'restricted_for_marketing': None,
#    'retrieved_at': '2014-04-09T18:41:49+00:00',
#    'source': {'publisher': 'Bahrain Ministry Of Industry And Commerce',
#     'retrieved_at': '2014-04-09T18:41:49+00:00',
#     'url': "http://www.moic.gov.bh/CReServices/inquiry/javascript:__doPostBack('grdCR$ctl07$lnkCrBr','')"},
#    'updated_at': '2014-04-09T23:48:04+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': 'F14031579',
#    'company_type': None,
#    'created_at': '2012-03-03T07:07:39+00:00',
#    'current_status': 'Incorporated',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '2011-03-24',
#    'jurisdiction_code': 'us_md',
#    'name': 'BARCLAYS BANK DELAWARE',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_md/F14031579',
#    'previous_names': [],
#    'registered_address': {'country': 'United States',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '100 S WEST ST\nWILMINGTON, DE 19801'},
#    'registered_address_in_full': '100 S WEST ST\nWILMINGTON, DE 19801',
#    'registry_url': 'http://sdatcert3.resiusa.org/UCC-Charter/Pages/CharterSearch/default.aspx',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-09-04T17:59:47+00:00',
#    'source': {'publisher': 'Maryland Department of Assessments & Taxation',
#     'retrieved_at': '2016-09-04T17:59:47+00:00',
#     'url': 'http://sdat.dat.maryland.gov/ucc-charter/Pages/CharterSearch/default.aspx'},
#    'updated_at': '2016-10-05T02:54:57+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '3227623',
#    'company_type': 'Corporation',
#    'created_at': '2015-10-15T00:29:27+00:00',
#    'current_status': None,
#    'dissolution_date': None,
#    'inactive': None,
#    'incorporation_date': '2001-03-21',
#    'jurisdiction_code': 'us_de',
#    'name': 'BARCLAYS BANK DELAWARE',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_de/3227623',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-07-21T02:35:45+00:00',
#    'source': {'publisher': 'Delaware Department of State: Division of Corporations',
#     'retrieved_at': '2016-07-21T02:35:45+00:00',
#     'url': 'http://www.corp.delaware.gov/'},
#    'updated_at': '2016-10-05T02:54:58+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': 'EXTUID_3204',
#    'company_type': 'RC - Registered Private Company',
#    'created_at': '2010-11-19T03:37:24+00:00',
#    'current_status': 'Dissolved',
#    'dissolution_date': '2003-05-28',
#    'inactive': True,
#    'incorporation_date': '1969-01-09',
#    'jurisdiction_code': 'je',
#    'name': 'BARCLAYS BANK FINANCE COMPANY (JERSEY) LIMITED',
#    'native_company_number': '3564',
#    'opencorporates_url': 'https://opencorporates.com/companies/je/EXTUID_3204',
#    'previous_names': [],
#    'registered_address': {'country': None,
#     'locality': 'St Helier',
#     'postal_code': None,
#     'region': None,
#     'street_address': '29/31 The Esplanade'},
#    'registered_address_in_full': '29/31 The Esplanade, St Helier',
#    'registry_url': 'https://www.jerseyfsc.org/registry/documentsearch/NameDetail.aspx?id=3204',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-22T23:16:27+00:00',
#    'source': {'publisher': 'Jersey Financial Services Commission',
#     'retrieved_at': '2016-11-22T23:16:27+00:00',
#     'url': 'https://www.jerseyfsc.org/registry/documentsearch/NameDetail.aspx?id=3204'},
#    'updated_at': '2016-11-23T00:18:49+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '10208960',
#    'company_type': 'Foreign Corp',
#    'created_at': '2016-01-23T00:54:09+00:00',
#    'current_status': 'Active',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '2015-05-13',
#    'jurisdiction_code': 'us_ne',
#    'name': 'BARCLAYS BANK INC',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_ne/10208960',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': 'https://www.nebraska.gov/sos/corp/corpsearch.cgi?acct-number=10208960',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-01-19T13:08:58+00:00',
#    'source': {'publisher': 'Nebraska Secretary of State',
#     'retrieved_at': '2016-01-19T13:08:58+00:00',
#     'url': 'https://www.nebraska.gov/sos/corp/corpsearch.cgi?acct-number=10208960'},
#    'updated_at': '2016-01-23T02:34:16+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': 'F001323223',
#    'company_type': 'Gen. Business - For Profit',
#    'created_at': '2016-02-21T02:23:16+00:00',
#    'current_status': 'Good Standing',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '2015-09-04',
#    'jurisdiction_code': 'us_mo',
#    'name': 'BARCLAYS BANK INC.',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_mo/F001323223',
#    'previous_names': [],
#    'registered_address': {'country': 'United States',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '120 South Central Ave\nClayton, MO 63105'},
#    'registered_address_in_full': '120 South Central Ave\nClayton, MO 63105',
#    'registry_url': 'https://bsd.sos.mo.gov/BusinessEntity/BusinessEntityDetail.aspx?page=beSearch&ID=3746202',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-08-04T03:18:35+00:00',
#    'source': {'publisher': 'Missouri Secretary of State',
#     'retrieved_at': '2016-08-04T03:18:35+00:00',
#     'url': 'https://bsd.sos.mo.gov/BusinessEntity/BusinessEntityDetail.aspx?page=beSearch&ID=3746202'},
#    'updated_at': '2016-08-08T14:11:18+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '0324949',
#    'company_type': 'Foreign Profit Corporation',
#    'created_at': '2016-12-01T04:14:54+00:00',
#    'current_status': 'Active',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '2016-11-28',
#    'jurisdiction_code': 'us_vt',
#    'name': 'BARCLAYS BANK INC.',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_vt/0324949',
#    'previous_names': [],
#    'registered_address': {'country': 'United States',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '1 Churchill Place, London, E145H, GBR'},
#    'registered_address_in_full': '1 Churchill Place, London, E145H, GBR',
#    'registry_url': 'https://www.vtsosonline.com/online/BusinessInquire/BusinessInformation?businessID=0324949',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2017-01-09T03:30:44+00:00',
#    'source': {'publisher': 'Vermont Secretary of State: Corporations Division',
#     'retrieved_at': '2017-01-09T03:30:44+00:00',
#     'url': 'http://www.sec.state.vt.us/corps/corp.htm'},
#    'updated_at': '2017-01-09T13:27:17+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '01048020',
#    'company_type': 'Private Limited Company',
#    'created_at': '2011-04-25T10:43:36+00:00',
#    'current_status': 'Dissolved',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': '1972-03-30',
#    'jurisdiction_code': 'gb',
#    'name': 'BARCLAYS BANK INTERNATIONAL INVESTMENTS HOLDINGS LIMITED',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/gb/01048020',
#    'previous_names': [],
#    'registered_address': {'country': 'United Kingdom',
#     'locality': 'LONDON',
#     'postal_code': 'EC4A 3TR',
#     'region': None,
#     'street_address': 'HILL HOUSE, 1 LITTLE NEW STREET'},
#    'registered_address_in_full': 'HILL HOUSE, 1 LITTLE NEW STREET, LONDON, EC4A 3TR',
#    'registry_url': 'https://beta.companieshouse.gov.uk/company/01048020',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2011-05-03T05:36:17+00:00',
#    'source': {'publisher': 'UK Companies House',
#     'retrieved_at': '2011-05-03T05:36:17+00:00',
#     'terms': 'UK Crown Copyright',
#     'url': 'http://xmlgw.companieshouse.gov.uk/'},
#    'updated_at': '2015-12-13T23:57:59+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '49396015',
#    'company_type': 'Anden udenlandsk virksomhed',
#    'created_at': '2016-01-01T21:07:17+00:00',
#    'current_status': None,
#    'dissolution_date': '1989-12-31',
#    'inactive': True,
#    'incorporation_date': '1974-09-20',
#    'jurisdiction_code': 'dk',
#    'name': 'BARCLAYS BANK INTERNATIONAL LTD',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/dk/49396015',
#    'previous_names': [{'company_name': 'BARCLAYS BANK INTERNATIONAL LTD',
#      'end_date': '1989-12-31',
#      'start_date': '1974-09-20'}],
#    'registered_address': {'country': 'Denmark',
#     'locality': 'København K',
#     'postal_code': '1061',
#     'region': None,
#     'street_address': 'Ved Stranden 8'},
#    'registered_address_in_full': 'Ved Stranden 8, København K, 1061',
#    'registry_url': 'http://datacvr.virk.dk/data/visenhed?enhedstype=virksomhed&id=49396015',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2017-01-02T01:09:15+00:00',
#    'source': {'publisher': 'Det centrale virksomhedsregister',
#     'retrieved_at': '2017-01-02T01:09:15+00:00',
#     'terms': 'Vilkår for brug af danske offentlige data/CVR.dk licence',
#     'terms_url': 'http://www.cvr.dk/Site/Forms/CMS/DisplayPage.aspx?pageid=91',
#     'url': 'http://datacvr.virk.dk/data/'},
#    'updated_at': '2017-01-12T01:05:35+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '1678',
#    'company_type': 'Private',
#    'created_at': '2011-07-25T05:32:46+00:00',
#    'current_status': 'Dissolved',
#    'dissolution_date': '1992-10-16',
#    'inactive': True,
#    'incorporation_date': '1893-08-15',
#    'jurisdiction_code': 'ie',
#    'name': 'BARCLAYS BANK IRELAND LIMITED',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ie/1678',
#    'previous_names': [],
#    'registered_address': {'country': 'Ireland',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': "47/49, ST. STEPHEN'S GREEN, DUBLIN 2."},
#    'registered_address_in_full': "47/49, ST. STEPHEN'S GREEN, DUBLIN 2.",
#    'registry_url': 'http://www.cro.ie/search/CompanyDetails.aspx?id=1678&type=C',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-29T13:11:45+00:00',
#    'source': {'publisher': 'Ireland Companies Registration Office',
#     'retrieved_at': '2016-11-29T13:11:45+00:00',
#     'terms': 'CRO Open Services licence',
#     'url': 'https://services.cro.ie/'},
#    'updated_at': '2016-11-29T13:11:45+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '396330',
#    'company_type': 'PLC - Public Limited Company',
#    'created_at': '2011-07-25T05:32:46+00:00',
#    'current_status': 'Normal',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '2005-01-12',
#    'jurisdiction_code': 'ie',
#    'name': 'BARCLAYS BANK IRELAND PUBLIC LIMITED COMPANY',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ie/396330',
#    'previous_names': [],
#    'registered_address': {'country': 'Ireland',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': 'TWO PARK PLACE, HATCH STREET, DUBLIN 2.'},
#    'registered_address_in_full': 'TWO PARK PLACE, HATCH STREET, DUBLIN 2.',
#    'registry_url': 'http://www.cro.ie/search/CompanyDetails.aspx?id=396330&type=C',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2017-01-03T00:38:31+00:00',
#    'source': {'publisher': 'Ireland Companies Registration Office',
#     'retrieved_at': '2017-01-03T00:38:31+00:00',
#     'terms': 'CRO Open Services licence',
#     'url': 'https://services.cro.ie/'},
#    'updated_at': '2017-01-03T00:38:31+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': 'Z13536230',
#    'company_type': None,
#    'created_at': '2012-03-03T07:07:40+00:00',
#    'current_status': 'Revived',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '2010-04-22',
#    'jurisdiction_code': 'us_md',
#    'name': 'BARCLAYS BANK LC A/K/A BARCLAYS BANK PLC',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_md/Z13536230',
#    'previous_names': [],
#    'registered_address': {'country': 'United States',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '1 CHURCHILL PL\nLONDON,'},
#    'registered_address_in_full': '1 CHURCHILL PL\nLONDON,',
#    'registry_url': 'http://sdatcert3.resiusa.org/UCC-Charter/Pages/CharterSearch/default.aspx',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-09-12T00:41:34+00:00',
#    'source': {'publisher': 'Maryland Department of Assessments & Taxation',
#     'retrieved_at': '2016-09-12T00:41:34+00:00',
#     'url': 'http://sdat.dat.maryland.gov/ucc-charter/Pages/CharterSearch/default.aspx'},
#    'updated_at': '2016-10-08T01:17:02+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '0726501',
#    'company_type': 'Foreign Corporation',
#    'created_at': '2015-06-22T20:51:03+00:00',
#    'current_status': 'I   Inactive',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': None,
#    'jurisdiction_code': 'us_ky',
#    'name': 'BARCLAYS BANK LIMITED',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_ky/0726501',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': 'https://app.sos.ky.gov/ftshow/(S(4g2sxj3uxdikdps4zvp2qtdl))/default.aspx?path=ftsearch&id=0726501&ct=09&cs=99999',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-10-12T06:34:44+00:00',
#    'source': {'publisher': 'Kentucky Secretary Of State',
#     'retrieved_at': '2016-10-12T06:34:44+00:00',
#     'url': 'https://app.sos.ky.gov/ftshow/(S(4g2sxj3uxdikdps4zvp2qtdl))/default.aspx?path=ftsearch&id=0726501&ct=09&cs=99999'},
#    'updated_at': '2016-10-25T02:26:57+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '0677543',
#    'company_type': 'Foreign Corporation',
#    'created_at': '2015-06-22T15:01:32+00:00',
#    'current_status': 'I   Inactive',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': None,
#    'jurisdiction_code': 'us_ky',
#    'name': 'BARCLAYS BANK LIMTED',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_ky/0677543',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': 'https://app.sos.ky.gov/ftshow/(S(1b2xjuppwki5twd4l5b14itt))/default.aspx?path=ftsearch&id=0677543&ct=09&cs=99999',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-10-06T08:08:31+00:00',
#    'source': {'publisher': 'Kentucky Secretary Of State',
#     'retrieved_at': '2016-10-06T08:08:31+00:00',
#     'url': 'https://app.sos.ky.gov/ftshow/(S(1b2xjuppwki5twd4l5b14itt))/default.aspx?path=ftsearch&id=0677543&ct=09&cs=99999'},
#    'updated_at': '2016-10-09T13:49:57+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': 'C0489490',
#    'company_type': 'Domestic Stock',
#    'created_at': '2011-09-14T21:24:05+00:00',
#    'current_status': 'Merged Out',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': '1965-04-20',
#    'jurisdiction_code': 'us_ca',
#    'name': 'BARCLAYS BANK OF CALIFORNIA',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_ca/C0489490',
#    'previous_names': [],
#    'registered_address': {'country': 'United States',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '111 PINE STREET STE. 200,\nSAN FRANCISCO, CA 94111'},
#    'registered_address_in_full': '111 PINE STREET STE. 200,\nSAN FRANCISCO, CA 94111',
#    'registry_url': 'https://businessfilings.sos.ca.gov/frmDetail.asp?CorpID=00489490',
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-24T08:22:47+00:00',
#    'source': {'publisher': 'California Secretary of State',
#     'retrieved_at': '2016-11-24T08:22:47+00:00',
#     'url': 'https://businessfilings.sos.ca.gov/frmDetail.asp?CorpID=00489490'},
#    'updated_at': '2016-12-10T20:59:16+00:00'}},
#  {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#    'company_number': '1956986',
#    'company_type': 'Extra-Provincial Financial Institution',
#    'created_at': '2012-09-27T01:51:12+00:00',
#    'current_status': 'Revoked By Request',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': '1989-06-01',
#    'jurisdiction_code': 'ca_ns',
#    'name': 'BARCLAYS BANK OF CANADA',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ca_ns/1956986',
#    'previous_names': [],
#    'registered_address': {'country': 'Canada',
#     'locality': None,
#     'postal_code': None,
#     'region': None,
#     'street_address': '304 BAY ST\nTORONTO ON Canada M5H2P2'},
#    'registered_address_in_full': '304 BAY ST\nTORONTO ON Canada M5H2P2',
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2015-10-19T09:08:00+00:00',
#    'source': {'publisher': 'Nova Scotia Registry of Joint Stock Companies',
#     'retrieved_at': '2015-10-19T09:08:00+00:00',
#     'url': 'https://rjsc.gov.ns.ca/rjsc/'},
#    'updated_at': '2015-10-29T18:20:30+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': 'Q08709',
#    'company_type': 'Declaration of Registered Agent',
#    'created_at': '2012-04-04T06:37:40+00:00',
#    'current_status': 'Inactive',
#    'dissolution_date': None,
#    'inactive': True,
#    'incorporation_date': '1985-03-13',
#    'jurisdiction_code': 'us_fl',
#    'name': 'BARCLAYS BANK OF NEW YORK',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/us_fl/Q08709',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2015-06-01T00:00:00+00:00',
#    'source': {'publisher': 'Florida Department of State Division of Corporations',
#     'retrieved_at': '2015-06-01T00:00:00+00:00',
#     'url': 'http://www.sunbiz.org'},
#    'updated_at': '2015-06-25T05:49:16+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '22399',
#    'company_type': 'Limited Company',
#    'created_at': '2014-06-01T05:05:25+00:00',
#    'current_status': 'Registered',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '1990-10-24',
#    'jurisdiction_code': 'ug',
#    'name': 'BARCLAYS BANK OF UGANDA (NOMINEES) LTD',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ug/22399',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-28T00:27:49+00:00',
#    'source': {'publisher': 'Uganda Registration Services Bureau ',
#     'retrieved_at': '2016-11-28T00:27:49+00:00',
#     'url': 'http://www.ursb.go.ug/'},
#    'updated_at': '2016-11-29T17:26:48+00:00'}},
#  {'company': {'branch_status': None,
#    'company_number': '4227',
#    'company_type': 'Limited Company',
#    'created_at': '2014-06-01T05:05:25+00:00',
#    'current_status': 'Registered',
#    'dissolution_date': None,
#    'inactive': False,
#    'incorporation_date': '1969-10-13',
#    'jurisdiction_code': 'ug',
#    'name': 'BARCLAYS BANK OF UGANDA LTD',
#    'native_company_number': None,
#    'opencorporates_url': 'https://opencorporates.com/companies/ug/4227',
#    'previous_names': [],
#    'registered_address': None,
#    'registered_address_in_full': None,
#    'registry_url': None,
#    'restricted_for_marketing': None,
#    'retrieved_at': '2016-11-28T00:27:49+00:00',
#    'source': {'publisher': 'Uganda Registration Services Bureau ',
#     'retrieved_at': '2016-11-28T00:27:49+00:00',
#     'url': 'http://www.ursb.go.ug/'},
#    'updated_at': '2016-11-29T17:26:26+00:00'}}]

# %%
data['results']['companies'][0]
# Out:
# {'company': {'branch_status': 'branch of an out-of-jurisdiction company',
#   'company_number': '0870373575',
#   'company_type': 'Entreprise étrangère',
#   'created_at': '2014-06-08T23:43:37+00:00',
#   'current_status': 'Société En Nom Collectif',
#   'dissolution_date': None,
#   'inactive': False,
#   'incorporation_date': '2004-12-03',
#   'jurisdiction_code': 'be',
#   'name': 'BARCLAYS BANK',
#   'native_company_number': None,
#   'opencorporates_url': 'https://opencorporates.com/companies/be/0870373575',
#   'previous_names': [],
#   'registered_address': {'country': 'Grande-Bretagne',
#    'locality': 'LONDON',
#    'postal_code': 'EC3P 3AM',
#    'region': None,
#    'street_address': 'LOMBARD STREET 54'},
#   'registered_address_in_full': 'LOMBARD STREET 54, LONDON, EC3P 3AM',
#   'registry_url': 'https://kbopub.economie.fgov.be/kbopub/toonondernemingps.html?lang=fr&ondernemingsnummer=0870373575',
#   'restricted_for_marketing': None,
#   'retrieved_at': '2016-12-02T00:00:00+00:00',
#   'source': {'publisher': 'La Banque-Carrefour des Entreprises',
#    'retrieved_at': '2016-12-02T00:00:00+00:00',
#    'url': 'http://economie.fgov.be/fr/entreprises/bce/pub/opendata/'},
#   'updated_at': '2016-12-15T22:59:29+00:00'}}

# %%
data['results']['companies'][0].keys()
# Out:
# dict_keys(['company'])

# %%
data['results']['companies'][5]['company']['name']
# Out:
# 'BARCLAYS BANK (SINGAPORE NOMINEES) PTE LTD'

# %% [markdown]
# # Exercise 3
# Print the names of the companies returned by the search "BARCLAYS BANK"

# %%
# write your solution here
for c in data['results']['companies']:
    name = c['company']['name']
    print(name)

# %% [markdown]
# <br style=margin:500px;>
# ___

# %%
# Class exercise solution

for c in data['results']['companies']:
    name = c['company']['name']
    print(name)
# Out:
# BARCLAYS BANK
# BARCLAYS BANK
# BARCLAYS BANK ( DOMINION COLONIAL AND OVERSSEAS)
# BARCLAYS BANK (HONG KONG NOMINEES) LIMITED
# BARCLAYS BANK (LONDON AND INTERNATIONAL) LIMITED
# BARCLAYS BANK (SINGAPORE NOMINEES) PTE LTD
# BARCLAYS BANK (SOUTH EAST ASIA) NOMINEES PTE LTD
# BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION
# BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION
# BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION
# BARCLAYS BANK AGRICULTURAL FINANCE CORPORATION CORPORATION FINANCIERE AGRICULTURELLE DE LA BANQUE BARCLAYS
# BARCLAYS BANK B.L.C
# BARCLAYS BANK DELAWARE
# BARCLAYS BANK DELAWARE
# BARCLAYS BANK FINANCE COMPANY (JERSEY) LIMITED
# BARCLAYS BANK INC
# BARCLAYS BANK INC.
# BARCLAYS BANK INC.
# BARCLAYS BANK INTERNATIONAL INVESTMENTS HOLDINGS LIMITED
# BARCLAYS BANK INTERNATIONAL LTD
# BARCLAYS BANK IRELAND LIMITED
# BARCLAYS BANK IRELAND PUBLIC LIMITED COMPANY
# BARCLAYS BANK LC A/K/A BARCLAYS BANK PLC
# BARCLAYS BANK LIMITED
# BARCLAYS BANK LIMTED
# BARCLAYS BANK OF CALIFORNIA
# BARCLAYS BANK OF CANADA
# BARCLAYS BANK OF NEW YORK
# BARCLAYS BANK OF UGANDA (NOMINEES) LTD
# BARCLAYS BANK OF UGANDA LTD

# %% [markdown]
# # (3) sqlite

# %%
# create new database file: from command prompot 'sqlite3', then .save "filename", then CTRL+C
# created empty_db.sql

# %%
# !ls
# Out:
# barclay_banks.txt
# csv.ipynb
# data pageviews-20160801-000000
# data_ex3.json
# data_out.csv
# data_sql_input.csv
# data1.csv
# data1_sep.csv
# data1modified.csv
# data2.csv
# data3.csv
# data4.csv
# data5missing.csv
# data6.zip
# data7longer.csv
# db.sqlite
# empty_db.sqlite
# html_example.html
# json and sql.ipynb
# json_data_format_columns.json
# json_data_format_index.json
# json_data_format_records.json
# json_data_format_split.json
# json_data_format_values.json
# json_example.json
# json_example2.json
# wikis by speakers - top 10.csv
# xml and web-scraping.ipynb
# xml_example.xml

# %%
# copy an empty database file "empty_db.sqlite" to a copy named "db"
# !cp "empty_db.sqlite" "db.sqlite"

# %%
import sqlite3
import pandas as pd

# %%
# typical workflow

con = sqlite3.connect('db.sqlite') # open connection
# perform some actions on database: create table, insert rows to tables, reterieve data, etc.
con.close() # close connection, important to prevent data losses

# %%
# Show metadata for database file
con = sqlite3.connect('db.sqlite')
df=pd.read_sql_query("SELECT * from sqlite_master", con)
con.close()
df
# Out:
#     type        name    tbl_name  rootpage  \
# 0  table         tbl         tbl         2
# 1  table  temp_table  temp_table         3
#
#                                                  sql
# 0  CREATE TABLE tbl(wikipedia TEXT, topic TEXT, y...
# 1  CREATE TABLE temp_table(topic TEXT,year INT,to...

# %% [markdown]
# ## Create sqlite table using csv file

# %%
# Create new table
con = sqlite3.connect('db.sqlite')
con.execute("CREATE TABLE tbl(wikipedia TEXT, topic TEXT, year INTEGER, month INTEGER, pageviews INTEGER);")
con.commit() # apply transaction

con.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-1f37b4b7f064> in <module>()
#       1 # Create new table
#       2 con = sqlite3.connect('db.sqlite')
# ----> 3 con.execute("CREATE TABLE tbl(wikipedia TEXT, topic TEXT, year INTEGER, month INTEGER, pageviews INTEGER);")
#       4 con.commit() # apply transaction
#       5 con.close()
#
# OperationalError: table tbl already exists

# %%
# Show metadata for database file
con = sqlite3.connect('db.sqlite')
df=pd.read_sql_query("SELECT * from sqlite_master", con)
con.close()
df
# Out:
#     type name tbl_name  rootpage  \
# 0  table  tbl      tbl         2
#
#                                                  sql
# 0  CREATE TABLE tbl(wikipedia TEXT, topic TEXT, y...

# %%
# delete table
con = sqlite3.connect('db.sqlite')
con.execute("DROP TABLE tbl")
con.commit()
con.close()

# %%
# Show metadata for database file
con = sqlite3.connect('db.sqlite')
pd.read_sql_query("SELECT * from sqlite_master", con)
# Out:
# Empty DataFrame
# Columns: [type, name, tbl_name, rootpage, sql]
# Index: []

# %%
# Create new table
con = sqlite3.connect('db.sqlite')
con.execute("CREATE TABLE tbl(wikipedia TEXT, topic TEXT, year INTEGER, month INTEGER, pageviews INTEGER);")
con.commit()
con.close()

# %%
# Show metadata for database file
con = sqlite3.connect('db.sqlite')
df=pd.read_sql_query("SELECT * from tbl", con)
con.close()
df
# Out:
# Empty DataFrame
# Columns: [wikipedia, topic, year, month, pageviews]
# Index: []

# %%
con = sqlite3.connect('db.sqlite')
con.execute("INSERT INTO tbl VALUES ('en','sqlite',1,2,3)")  
con.commit() 
con.close()

# %%
# Show metadata for database file
con = sqlite3.connect('db.sqlite')
df=pd.read_sql_query("SELECT * from tbl", con)
con.close()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-167b5ae9f02f> in <module>()
#       1 # Show metadata for database file
# ----> 2 con = sqlite3.connect('db.sqlite')
#       3 df=pd.read_sql_query("SELECT * from tbl", con)
#       4 con.close()
#       5 df
#
# NameError: name 'sqlite3' is not defined

# %% [markdown]
# ## Import csv file to database

# %%
# fill the database file with the content of "data_sql_input.csv"
# !head -5 "data_sql_input.csv"
# Out:
# wikipedia,topic,year,month,pageviews
# en,sqlite,2010,1,594
# en,sqlite,2010,2,100
# en,sqlite,2010,3,534
# en,sqlite,2010,4,274

# %%
# Fill table with data from csv file
import csv
con = sqlite3.connect('db.sqlite')
csvfile = open('data_sql_input.csv')
csvReader = csv.reader(csvfile)
header = next(csvReader) # skip first row (header)
for rec in csvReader: # iterate over the other rows
    con.execute("INSERT INTO tbl VALUES %s"%str(tuple(rec)))  
csvfile.close()    
con.commit() 
con.close()
# for large data files, commiting multiple time during the execution may be necessary
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
# Query database table using pandas
con = sqlite3.connect('db.sqlite')
df = pd.read_sql_query("SELECT * FROM tbl", con)
con.close()
df
# Out:
#    wikipedia     topic  year  month  pageviews
# 0         en    sqlite     1      2          3
# 1         en    sqlite  2010      1        594
# 2         en    sqlite  2010      2        100
# 3         en    sqlite  2010      3        534
# 4         en    sqlite  2010      4        274
# 5         en    sqlite  2010      5        600
# 6         en    sqlite  2010      6        264
# 7         en    sqlite  2010      7        184
# 8         en    sqlite  2010      8        246
# 9         en    sqlite  2010      9        162
# 10        en    sqlite  2010     10        426
# 11        en    sqlite  2010     11        579
# 12        en    sqlite  2010     12        149
# 13        en    sqlite  2011      1        441
# 14        en    sqlite  2011      2        513
# 15        en    sqlite  2011      3        180
# 16        en    sqlite  2011      4        492
# 17        en    sqlite  2011      5        575
# 18        en    sqlite  2011      6        516
# 19        en    sqlite  2011      7        344
# 20        en    sqlite  2011      8        588
# 21        en    sqlite  2011      9        705
# 22        en    sqlite  2011     10        392
# 23        en    sqlite  2011     11        546
# 24        en    sqlite  2011     12        137
# 25        en  database  2010      1        375
# 26        en  database  2010      2        375
# 27        en  database  2010      3        370
# 28        en  database  2010      4        585
# 29        en  database  2010      5        296
# 30        en  database  2010      6        266
# 31        en  database  2010      7        372
# 32        en  database  2010      8        260
# 33        en  database  2010      9        432
# 34        en  database  2010     10        298
# 35        en  database  2010     11        480
# 36        en  database  2010     12        218
# 37        en  database  2011      1        306
# 38        en  database  2011      2        163
# 39        en  database  2011      3        715
# 40        en  database  2011      4        488
# 41        en  database  2011      5        504
# 42        en  database  2011      6        684
# 43        en  database  2011      7        292
# 44        en  database  2011      8        292
# 45        en  database  2011      9        590
# 46        en  database  2011     10        644
# 47        en  database  2011     11        585
# 48        en  database  2011     12        880

# %%
# Filter rows
con = sqlite3.connect('db.sqlite')
df = pd.read_sql_query("""SELECT * 
                            FROM tbl 
                            WHERE month=2""", con)
con.close()
df.head()
# Out:
#   wikipedia     topic  year  month  pageviews
# 0        en    sqlite     1      2          3
# 1        en    sqlite  2010      2        100
# 2        en    sqlite  2011      2        513
# 3        en  database  2010      2        375
# 4        en  database  2011      2        163

# %%
# Aggregate data
con = sqlite3.connect('db.sqlite')
df = pd.read_sql_query("""SELECT topic,year,sum(pageviews)
                            FROM tbl 
                            GROUP BY topic,year;""", con)

con.close()
df.head()
# Out:
#       topic  year  sum(pageviews)
# 0  database  2010            4327
# 1  database  2011            6143
# 2    sqlite     1               3
# 3    sqlite  2010            4112
# 4    sqlite  2011            5429

# %%
# Create table from query 
con = sqlite3.connect('db.sqlite')
con.execute("""CREATE TABLE temp_table AS
                        SELECT topic, year, sum(pageviews) as total 
                        FROM tbl 
                        GROUP BY topic,year;
                        """) # the function assumes that "temp_table" does not exist; use DROP if necessary 
con.commit()
con.close()

# %%
# Query newly created table
con = sqlite3.connect('db.sqlite')
print(pd.read_sql_query("SELECT * FROM temp_table", con))
con.close()
# Out:
#       topic  year  total
# 0  database  2010   4327
# 1  database  2011   6143
# 2    sqlite     1      3
# 3    sqlite  2010   4112
# 4    sqlite  2011   5429

# %%
# Create table from query  (requires that the table already exists)
con = sqlite3.connect('db.sqlite')
con.execute("""INSERT INTO temp_table
                        SELECT topic,year,sum(pageviews)  
                        FROM tbl 
                        GROUP BY topic,year;
                        """)
con.commit()
con.close()

# %%
# limit the returned query to 2 rows
con = sqlite3.connect('db.sqlite')
print(pd.read_sql_query("SELECT * FROM temp_table LIMIT 2", con))
con.close()
# Out:
#       topic  year  total
# 0  database  2010   4327
# 1  database  2011   6143

# %%
# Sort output (according to decreasing order)
con = sqlite3.connect('db.sqlite')
print(pd.read_sql_query("SELECT * FROM temp_table ORDER BY total DESC", con))
con.close()
# Out:
#       topic  year  total
# 0  database  2011   6143
# 1  database  2011   6143
# 2    sqlite  2011   5429
# 3    sqlite  2011   5429
# 4  database  2010   4327
# 5  database  2010   4327
# 6    sqlite  2010   4112
# 7    sqlite  2010   4112
# 8    sqlite     1      3
# 9    sqlite     1      3

# %%
# Sort output (increasing by year, then decreasing by total pageviews)
con = sqlite3.connect('db.sqlite')
print(pd.read_sql_query("SELECT * FROM temp_table ORDER BY year ASC, total DESC", con))
con.close()
# Out:
#       topic  year  total
# 0    sqlite     1      3
# 1    sqlite     1      3
# 2  database  2010   4327
# 3  database  2010   4327
# 4    sqlite  2010   4112
# 5    sqlite  2010   4112
# 6  database  2011   6143
# 7  database  2011   6143
# 8    sqlite  2011   5429
# 9    sqlite  2011   5429
